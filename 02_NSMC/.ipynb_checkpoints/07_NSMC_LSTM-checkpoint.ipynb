# %% [markdown]
# # 네이버 영화리뷰 감정분석 with LSTM
# 참고 소스 출처(링크) : 텐서플로2와 머신러닝으로 시작하는 자연어 처리(전창욱 외, 위키북스, 2020)

# %% [markdown]
# # 준비
# 라이브러리, 파라미터 세팅

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras import layers

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import json
from tqdm import tqdm
import re
import json
import time

from konlpy.tag import Okt
from tensorflow.python.keras.preprocessing.sequence import pad_sequences
from tensorflow.python.keras.preprocessing.text import Tokenizer

# %%
# 시각화 함수
def plot_graphs(history, string):
    plt.plot(history.history[string])
    plt.plot(history.history['val_'+string], '')
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.legend([string, 'val_'+string])
    plt.show()

# %%
DATA_IN_PATH = './data_in/'
DATA_OUT_PATH = './data_out/'

TEST_SIZE = 0.2
RANDOM_SEED = 42

# tf.random.set_seed 함수를 이용해 시드를 고정하여 학습 관련 랜덤 변수에 대한 초기 상태를 유지
tf.random.set_seed(RANDOM_SEED)

# %% [markdown]
# 모델을 구현할 때 가장 중요한 것은 내가 학습한 상황을 그대로 보존하는 것이다.<br>
# 아무리 모델이 좋은 성능을 내더라도 그 성능이 재현되지 않으면 모델 검증을 할 수 없다.<br>
# 랜덤 시드를 고정하는 것은 모델과 샘플링을 하는 모든 랜덤 변수의 상태를 고정하기 위한 것이다.<br>
# tf.random.set_seed 함수를 이용해 랜덤 시드를 고정하면 학습을 하기 위한 랜덤 변수에 대한 초기 상태를 유지할 수 있다.

# %% [markdown]
# # 데이터 로드

# %%
train_data = pd.read_csv(DATA_IN_PATH+'ratings_train.txt', sep='\t')
train_data.head()
# Out:
#          id                                           document  label
# 0   9976970                                아 더빙.. 진짜 짜증나네요 목소리      0
# 1   3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2  10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3   9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4   6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1

# %%
# 검증 데이터 로드
dev_data = pd.read_csv(DATA_IN_PATH + 'ratings_test.txt', sep='\t')
dev_data.head()
# Out:
#         id                                           document  label
# 0  6270596                                                굳 ㅋ      1
# 1  9274899                               GDNTOPCLASSINTHECLUB      0
# 2  8544678             뭐야 이 평점들은.... 나쁘진 않지만 10점 짜리는 더더욱 아니잖아      0
# 3  6825595                   지루하지는 않은데 완전 막장임... 돈주고 보기에는....      0
# 4  6723715  3D만 아니었어도 별 다섯 개 줬을텐데.. 왜 3D로 나와서 제 심기를 불편하게 하죠??      0

# %%
# 테스트(캐글) 데이터 로드
test_data = pd.read_csv(DATA_IN_PATH + 'ko_data.csv', encoding = 'cp949')
test_data.columns = ['id','document']  # 전처리 일괄 수행을 위해 컬럼명 변경(학습 데이터셋과 동일하게)
test_data.head()
# Out:
#    id                                document
# 0   0                        정말 많이 울었던 영화입니다.
# 1   1                                시간 낭비예요.
# 2   2  포스터를 저렇게밖에 만들지 못했던 제작자의 소심함에 침을 뱉고 싶다.
# 3   3    지금 봐도 재미있는 영화!!! 코믹과 감동!!! 그리고 요리!!!
# 4   4               이걸 영화로 만드는 거야?얼마나 가는지 보자.

# %% [markdown]
# # 데이터 전처리

# %% [markdown]
# 정규표현식을 활용해 한글 문자가 아닌 것들을 모두 제거한다.<br>
#
# 한글을 범위 지정할 수 있는 정규 표현식은 다음 내용을 참고한다. 우선 자음과 모음에 대한 범위를 지정한다. 일반적으로 자음의 범위는 ㄱ ~ ㅎ, 모음의 범위는 ㅏ ~ ㅣ와 같이 지정할 수 있다. 해당 범위 내에 속하는 자음과 모음은 아래의 링크를 참고하여 확인한다.<br>
# https://www.unicode.org/charts/PDF/U3130.pdf<br>
# ㄱ ~ ㅎ: 3131 ~ 314E<br>
# ㅏ ~ ㅣ: 314F ~ 3163
#
# 또한 완성형 한글의 범위는 가 ~ 힣과 같이 사용한다. 해당 범위 내에 포함된 음절들은 아래의 링크에서 확인할 수 있다.
# https://www.unicode.org/charts/PDF/UAC00.pdf
#
# 위의 범위 지정을 모두 반영하여 데이터셋에서 한글과 공백을 제외하고 모두 제거하는 정규 표현식을 수행한다.

# %%
review_text = re.sub("[^가-힣ㄱ-ㅎㅏ-ㅣ\\s]", "", train_data['document'][0]) 
print(review_text)
# Out:
# 아 더빙 진짜 짜증나네요 목소리

# %% [markdown]
# 특수문자가 모두 제거 되었으며, 이제 불용어를 제거하기 위해 문장을 단어로 나눠야 한다.<br>
# KoNLPy 라이브러리의 okt 객체를 사용한다. 그리고 형태소 분석기를 사용할 때 어간이 추출된 단어로 나눈다.

# %%
okt = Okt()
review_text = okt.morphs(review_text, stem=True)
print(review_text)
# Out:
# ['아', '더빙', '진짜', '짜증나다', '목소리']

# %% [markdown]
# 결과를 보면 형태소 분석기를 사용해서 문장이 각 단어로 나눠져 있는 것을 확인할 수 있다.<br>
# 다음으로 불용어(stop words)를 제거해야 하는데, 한글 불용어가 따로 정의되어 있는 파이썬 라이브러리가 없기 때문에<br>
# 직접 불용어 사전을 만든 뒤 그 사전을 통해 제거해야 한다. (다음 코드는 예시)<br>
# 데이터에 따라 불용어를 제거하지 않고 넘어가도 괜찮을 수 있다.

# %%
stop_words = set(['은','는','이','가','하','아','것','들','의','있','되','수','보','주','등','한'])
clean_review = [token for token in review_text if not token in stop_words]
print(clean_review)
# Out:
# ['더빙', '진짜', '짜증나다', '목소리']

# %% [markdown]
# 불용어까지 제거했다면 어느 정도 데이터가 정제됐다고 볼 수 있다.<br>
# 이제 전체 데이터에 적용하고 재사용하기 쉽게 전처리 과정을 하나의 함수로 만든다.

# %%
def preprocessing(review, okt, remove_stopwords = False, stop_words = []):
    # 함수의 인자는 다음과 같다.
    # review : 전처리 할 텍스트
    # okt : okt 객체를 반복적으로 생성하지 않고 미리 생성한 후 인자로 받는다.
    # remove_stopwords : 불용어를 제거할지 여부 선택. 기본값은 False
    # stop_words : 불용어 사전은 사용자가 직접 입력해야 함. 기본값은 빈 리스트
    
    # 1. 한글 및 공백을 제외한 문자를 모두 제거
    review_text = re.sub("[^가-힣ㄱ-ㅎㅏ-ㅣ\\s]", "", review)
    
    # 2. okt 객체를 활용해 형태소 단위로 나눈다.
    review_word = okt.morphs(review_text, stem=True)
    
    # 3. 불용어 제거(선택적 수행)
    if remove_stopwords:
        review_word = [token for token in review_word if not token in stop_words]
        
    return review_word

# %% [markdown]
# 한글을 제외한 모든 문자 제거, 형태소 토크나이징, 불용어 제거 순으로 진행되도록 함수를 정의했다.<br>
# 전처리 과정을 함수로 정의했으니 학습 데이터에 대해 전처리를 진행해 본다.<br>
# okt 객체를 생성하고 불용어 사전을 정의한 후 함수를 실행하면 된다.

# %%
stop_words = ['은','는','이','가','하','아','것','들','의','있','되','수','보','주','등','한']
okt = Okt()

# %%
clean_train_review = []

for review in train_data['document']:
    # 비어있는 데이터에서 멈추지 않도록 문자열인 경우에만 진행
    if type(review) == str:
        clean_train_review.append(preprocessing(review, okt, remove_stopwords=True, stop_words=stop_words))
    else:
        clean_train_review.append([])  # string이 아니면 비어있는 값 추가

clean_train_review[:4]  # 맨 앞 4개 데이터 확인
# Out:
# [['더빙', '진짜', '짜증나다', '목소리'],
#  ['흠', '포스터', '보고', '초딩', '영화', '줄', '오버', '연기', '조차', '가볍다', '않다'],
#  ['너', '무재', '밓었', '다그', '래서', '보다', '추천', '다'],
#  ['교도소', '이야기', '구먼', '솔직하다', '재미', '없다', '평점', '조정']]

# %% [markdown]
# 이제 해당 리뷰를 인덱스 벡터로 변환하면 되는데,<br>
# 평가 데이터도 동일하게 진행하기 때문에 평가 데이터에 대해서도 앞 과정을 똑같이 수행한다.

# %%
clean_dev_review = []

for review in dev_data['document']:
    # 비어있는 데이터에서 멈추지 않도록 string인 경우만 진행
    if type(review) == str:
        clean_dev_review.append(preprocessing(review, okt, remove_stopwords = True, stop_words=stop_words))
    else:
        clean_dev_review.append([])  #string이 아니면 비어있는 값 추가

clean_dev_review[:4]  # 맨 앞 4개 데이터 확인
# Out:
# [['굳다', 'ㅋ'],
#  [],
#  ['뭐', '야', '평점', '나쁘다', '않다', '점', '짜다', '리', '더', '더욱', '아니다'],
#  ['지루하다', '않다', '완전', '막장', '임', '돈', '주다', '보기', '에는']]

# %% [markdown]
# 이제 학습 데이터와 평가 데이터에 대해 인덱스 벡터로 바꾼 후 패딩 처리만 하면 모든 전처리 과정이 끝난다.<br>
# 텐서플로의 전처리 모듈을 사용하는데, 토크나이징 객체를 만든 후 학습 데이터에 대해서만 적용하고<br>
# 해당 객체를 사용해 두 데이터를 인덱스 벡터로 만든다. 그다음 마지막으로 해당 데이터들을 패딩 처리하면 된다.

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(clean_train_review)
train_sequences = tokenizer.texts_to_sequences(clean_train_review)
dev_sequences = tokenizer.texts_to_sequences(clean_dev_review)

word_vocab = tokenizer.word_index # 단어 사전 형태
word_vocab["<PAD>"] = 0

# %%
MAX_SEQUENCE_LENGTH = 8  # 문장 최대 길이

train_inputs = pad_sequences(train_sequences, maxlen=MAX_SEQUENCE_LENGTH, padding='post')  # 학습 데이터를 벡터화
train_labels = np.array(train_data['label']) # 학습 데이터의 라벨

dev_inputs = pad_sequences(dev_sequences, maxlen=MAX_SEQUENCE_LENGTH, padding='post')  # 검증 데이터를 벡터화
dev_labels = np.array(dev_data['label']) # 검증 데이터의 라벨

# %% [markdown]
# 데이터 분석 과정에서 단어의 평균 개수가 대략 8개 언더였기에 패딩 처리를 할 때 최대 길이를 8로 정한 것이다.<br>
# 이처럼 학습 데이터와 평가 데이터에 대해 입력값과 라벨값을 만들었다면 해당 데이터들을 모델링 과정에서 사용할 수 있게 저장해둔다.

# %%
DATA_IN_PATH = './data_in/'
TRAIN_INPUT_DATA = 'nsmc_train_input.npy'
TRAIN_LABEL_DATA = 'nsmc_train_label.npy'
DEV_INPUT_DATA = 'nsmc_dev_input.npy'
DEV_LABEL_DATA = 'nsmc_dev_label.npy'
DATA_CONFIGS = 'data_configs.json'

data_configs = {}

data_configs['vocab'] = word_vocab
data_configs['vocab_size'] = len(word_vocab) # vocab size 추가

# 저장하는 디렉토리가 존재하지 않으면 생성
if not os.path.exists(DATA_IN_PATH):
    os.makedirs(DATA_IN_PATH)

# 전처리 된 학습 데이터를 넘파이 형태로 저장
np.save(open(DATA_IN_PATH + TRAIN_INPUT_DATA, 'wb'), train_inputs)
np.save(open(DATA_IN_PATH + TRAIN_LABEL_DATA, 'wb'), train_labels)
# 전처리 된 검증 데이터를 넘파이 형태로 저장
np.save(open(DATA_IN_PATH + DEV_INPUT_DATA, 'wb'), dev_inputs)
np.save(open(DATA_IN_PATH + DEV_LABEL_DATA, 'wb'), dev_labels)

# 데이터 사전을 json 형태로 저장
json.dump(data_configs, open(DATA_IN_PATH + DATA_CONFIGS, 'w'), ensure_ascii=False)

# %% [markdown]
# 이제 전처리 과정이 모두 끝났다.
# 넘파이 배열은 지정한 경로에 nsmc_train_input.npy, nsmc_dev_label.npy로 각각 저장된다.
# 이제 전처리한 데이터를 활용해 감정 분석을 할 수 있는 모델을 만들어 본다.

# %%
DATA_IN_PATH = './data_in/'
DATA_OUT_PATH = './data_out/'
INPUT_TRAIN_DATA = 'nsmc_train_input.npy'
LABEL_TRAIN_DATA = 'nsmc_train_label.npy'
DATA_CONFIGS = 'data_configs.json'

train_input = np.load(open(DATA_IN_PATH + INPUT_TRAIN_DATA, 'rb'))
train_input = pad_sequences(train_input, maxlen=train_input.shape[1])
train_label = np.load(open(DATA_IN_PATH + LABEL_TRAIN_DATA, 'rb'))
prepro_configs = json.load(open(DATA_IN_PATH + DATA_CONFIGS, 'r'))

# %% [markdown]
# 데이터를 전처리하면서 입력 텍스트와 데이터 라벨을 numpy.Array 형식으로 저장했기 때문에 np.load로 데이터를 불러올 수 있다.<br>
# 입력 텍스트 데이터는 train_input에, 데이터 라벨은 train_label에 할당한다.<br>
#
# 여기서 입력 텍스트에 대해서는 모델을 학습할 때 텍스트 길이를 맞추기 위해<br>
# tensorflow.keras.preprocessing.sequence 모듈에 있는 pad_sequences 함수를 사용한다.<br>
# 이 함수는 최대 길이를 설정해 모든 데이터에 대한 길이를 최대 길이에 맞추는 역할을 한다.<br>
# 데이터 텍스트의 길이보다 길면 길이를 제한하고, 최대 길이보다 짧으면 패딩(padding) 토큰을 넣는다.<br>
#
# 데이터에 대한 사전정보를 데이터 전처리를 통해 json 파일에 저장했는데,<br>
# 이 사전정보는 모델에 있는 단어 임베딩 크기를 정의할 때 활용된다.<br>
#
# 이제 불러온 데이터를 모델에 적용한다.<br>
# 그전에 우선 학습 데이터의 일부를 검증 데이터로 분리해서 모델의 성능을 측정해야 한다.

# %% [markdown]
# ### 파라미터 정의

# %% [markdown]
# 모델에 필요한 하이퍼파라미터를 정의해본다.<br>
# 모델 학습 설정, 모델 레이어 차원 수 등으로 나누고, 학습을 위한 배치 크기 등은 변수로 지정한 후,<br>
# 모델에 필요한 내용은 모델 	&#95;&#95;init&#95;&#95; 함수의 파라미터에 입력하기 위해 dict 객체로 정의한다.<br>
# 각 모델 레이어 차원 수나 드롭아웃을 정하는 하이퍼파라미터 명칭은 key에,<br>
# 키에 해당하는 하이퍼파라미터 명칭에 대한 값은 value에 입력한다.

# %%
model_name = 'rnn_classifier_en'
BATCH_SIZE = 128
NUM_EPOCHS = 5  # 5
VALID_SPLIT = 0.1  # 0.1 or TEST_SIZE
MAX_LEN = train_input.shape[1]

kargs = {'model_name': model_name,
        'vocab_size': prepro_configs['vocab_size'],
        'embedding_dimension': 100,  # 100
        'dropout_rate': 0.2,  # 0.2
        'lstm_dimension': 150,  # 150
        'dense_dimension': 150,  # 150
        'output_dimension':1}

# %% [markdown]
# # 모델 생성

# %% [markdown]
# 학습 데이터와 모델 하이퍼파라미터가 준비됐으니 모델을 구현해 본다.<br>
# 모델은 tensorflow.keras 기반으로 클래스로 모델을 정의해서 구현한다.<br>
# 본 케이스는 합성곱 신경망 모델을 사용한다.

# %%
class RNNClassifier(tf.keras.Model):
    def __init__(self, **kargs):
        super(RNNClassifier, self).__init__(name=kargs['model_name'])
        self.embedding = layers.Embedding(input_dim=kargs['vocab_size'],
                                     output_dim=kargs['embedding_dimension'])
        self.lstm_1_layer = tf.keras.layers.LSTM(kargs['lstm_dimension'], return_sequences=True)
        self.lstm_2_layer = tf.keras.layers.LSTM(kargs['lstm_dimension'])
        self.dropout = layers.Dropout(kargs['dropout_rate'])
        self.fc1 = layers.Dense(units=kargs['dense_dimension'],
                           activation=tf.keras.activations.tanh)
        self.fc2 = layers.Dense(units=kargs['output_dimension'],
                           activation=tf.keras.activations.sigmoid)
    
    def call(self, x):
        x = self.embedding(x)
        x = self.dropout(x)
        x = self.lstm_1_layer(x)
        x = self.lstm_2_layer(x)
        x = self.dropout(x)
        x = self.fc1(x)
        x = self.dropout(x)
        x = self.fc2(x)
        
        return x

# %%
# 재현율, 정밀도, F1-Score 성능 측정 함수
from keras import backend as K

# 재현율
def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

# 정밀도
def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

# F1-Score
def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# # compile the model
# model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc',f1_m,precision_m, recall_m])

# # fit the model
# history = model.fit(Xtrain, ytrain, validation_split=0.3, epochs=10, verbose=0)

# # evaluate the model
# loss, accuracy, f1_score, precision, recall = model.evaluate(Xtest, ytest, verbose=0)

# %% [markdown]
# # 모델 학습

# %%
model = RNNClassifier(**kargs)

model.compile(optimizer=tf.keras.optimizers.Adam(1e-4),
              loss=tf.keras.losses.BinaryCrossentropy(),
              #metrics=[tf.keras.metrics.BinaryAccuracy(name='accuracy')])
              metrics=[tf.keras.metrics.BinaryAccuracy(name='accuracy'),f1_m,precision_m, recall_m])

# %% [markdown]
# 검증 정확도를 통한 EarlyStopping 기능과 모델 저장 방식을 지정하고,<br>
# 모델을 검증하기 위한 검증 데이터도 model.fit 안에 있는 validation_split로 지정한 다음 학습을 시작한다.

# %%
# overfitting을 막기 위한 ealrystop 추가
earlystop_callback = EarlyStopping(monitor='val_accuracy', min_delta=0.0001, patience=1)
# min_delta: the threshold that triggers the termination (acc should at least improve 0.0001)
# patience: no improvment epochs (patience = 1, 1번 이상 상승이 없으면 종료)

checkpoint_path = DATA_OUT_PATH + model_name + '/weights_rnn.h5'
checkpoint_dir = os.path.dirname(checkpoint_path)

# Create path if exists
if os.path.exists(checkpoint_dir):
    print("{} -- Folder already exists \n".format(checkpoint_dir))
else:
    os.makedirs(checkpoint_dir, exist_ok=True)
    print("{} -- Folder create complete \n".format(checkpoint_dir))
    

cp_callback = ModelCheckpoint(
    checkpoint_path, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=True)
# Out:
# ./data_out/rnn_classifier_en -- Folder already exists

# %%
history = model.fit(train_input, train_label, batch_size=BATCH_SIZE, epochs=NUM_EPOCHS,
                    validation_split=VALID_SPLIT, callbacks=[earlystop_callback, cp_callback])
# Out:
# Epoch 1/5
# 1055/1055 [==============================] - ETA: 0s - loss: 0.4878 - accuracy: 0.7552 - f1_m: 0.7589 - precision_m: 0.7599 - recall_m: 0.7687
# Epoch 00001: val_accuracy improved from -inf to 0.80713, saving model to ./data_out/rnn_classifier_en/weights_rnn.h5
# 1055/1055 [==============================] - 20s 19ms/step - loss: 0.4878 - accuracy: 0.7552 - f1_m: 0.7589 - precision_m: 0.7599 - recall_m: 0.7687 - val_loss: 0.4116 - val_accuracy: 0.8071 - val_f1_m: 0.8048 - val_precision_m: 0.8005 - val_recall_m: 0.8115
# Epoch 2/5
# 1053/1055 [============================>.] - ETA: 0s - loss: 0.3881 - accuracy: 0.8252 - f1_m: 0.8230 - precision_m: 0.8294 - recall_m: 0.8195
# Epoch 00002: val_accuracy improved from 0.80713 to 0.81747, saving model to ./data_out/rnn_classifier_en/weights_rnn.h5
# 1055/1055 [==============================] - 20s 19ms/step - loss: 0.3881 - accuracy: 0.8252 - f1_m: 0.8230 - precision_m: 0.8294 - recall_m: 0.8195 - val_loss: 0.3960 - val_accuracy: 0.8175 - val_f1_m: 0.8091 - val_precision_m: 0.8294 - val_recall_m: 0.7920
# Epoch 3/5
# 1053/1055 [============================>.] - ETA: 0s - loss: 0.3602 - accuracy: 0.8419 - f1_m: 0.8401 - precision_m: 0.8453 - recall_m: 0.8372
# Epoch 00003: val_accuracy improved from 0.81747 to 0.82020, saving model to ./data_out/rnn_classifier_en/weights_rnn.h5
# 1055/1055 [==============================] - 19s 18ms/step - loss: 0.3603 - accuracy: 0.8418 - f1_m: 0.8399 - precision_m: 0.8452 - recall_m: 0.8371 - val_loss: 0.3961 - val_accuracy: 0.8202 - val_f1_m: 0.8144 - val_precision_m: 0.8246 - val_recall_m: 0.8068
# Epoch 4/5
# 1055/1055 [==============================] - ETA: 0s - loss: 0.3434 - accuracy: 0.8514 - f1_m: 0.8497 - precision_m: 0.8540 - recall_m: 0.8475
# Epoch 00004: val_accuracy improved from 0.82020 to 0.82087, saving model to ./data_out/rnn_classifier_en/weights_rnn.h5
# 1055/1055 [==============================] - 20s 19ms/step - loss: 0.3434 - accuracy: 0.8514 - f1_m: 0.8497 - precision_m: 0.8540 - recall_m: 0.8475 - val_loss: 0.4013 - val_accuracy: 0.8209 - val_f1_m: 0.8179 - val_precision_m: 0.8162 - val_recall_m: 0.8219
# Epoch 5/5
# 1053/1055 [============================>.] - ETA: 0s - loss: 0.3298 - accuracy: 0.8574 - f1_m: 0.8556 - precision_m: 0.8596 - recall_m: 0.8539
# Epoch 00005: val_accuracy improved from 0.82087 to 0.82107, saving model to ./data_out/rnn_classifier_en/weights_rnn.h5
# 1055/1055 [==============================] - 20s 19ms/step - loss: 0.3299 - accuracy: 0.8573 - f1_m: 0.8556 - precision_m: 0.8595 - recall_m: 0.8538 - val_loss: 0.4022 - val_accuracy: 0.8211 - val_f1_m: 0.8184 - val_precision_m: 0.8170 - val_recall_m: 0.8221

# %% [markdown]
# 학습 결과를 통해 학습 및 검증 정확도와 loss 값을 확인할 수 있다.<br>
# 성능 그래프를 출력한다.

# %%
plot_graphs(history, 'loss')

# %%
plot_graphs(history, 'accuracy')

# %% [markdown]
# 이제 학습된 모델을 활용해 검증 작업을 시작한다.

# %% [markdown]
# # 모델 테스트 - 검증 데이터(Original 테스트 데이터셋) 성능 평가

# %% [markdown]
# 테스트 데이터에 감정에 대한 라벨 값이 있는 경우이므로, 바로 결과를 확인할 수 있다.<br>
# 테스트 데이터를 불러올 때 학습 데이터를 전처리하는 과정과 동일하게 진행한 후 넘파이 파일로 저장한 데이터를 불러오면 된다.

# %%
DATA_OUT_PATH = './data_out/'
INPUT_DEV_DATA = 'nsmc_dev_input.npy'
LABEL_DEV_DATA = 'nsmc_dev_label.npy'
SAVE_FILE_NM = 'weights_rnn.h5'  #저장된 best model 이름

dev_input = np.load(open(DATA_IN_PATH + INPUT_DEV_DATA, 'rb'))
dev_input = pad_sequences(dev_input, maxlen=dev_input.shape[1])
dev_label_data = np.load(open(DATA_IN_PATH + LABEL_DEV_DATA, 'rb'))

# %%
# model.load_weights(os.path.join(DATA_OUT_PATH, model_name, SAVE_FILE_NM))
# model.evaluate(dev_input, dev_label_data)

# # 1563/1563 [==============================] - 4s 2ms/step - loss: 0.4024 - accuracy: 0.8186
# # [0.40237167477607727, 0.818560004234314]

# %%
model.load_weights(os.path.join(DATA_OUT_PATH, model_name, SAVE_FILE_NM))

# evaluate the model
loss, accuracy, f1_score, precision, recall = model.evaluate(dev_input, dev_label_data)
# Out:
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.4061 - accuracy: 0.8203 - f1_m: 0.8173 - precision_m: 0.8207 - recall_m: 0.8237

# %% [markdown]
# # (참고) 제출 파일 생성

# %%
clean_test_review = []

for review in test_data['document']:
    # 비어있는 데이터에서 멈추지 않도록 문자열인 경우에만 진행
    if type(review) == str:
        clean_test_review.append(preprocessing(review, okt, remove_stopwords=True, stop_words=stop_words))
    else:
        clean_test_review.append([])  # string이 아니면 비어있는 값 추가

clean_test_review[:4]  # 맨 앞 4개 데이터 확인
# Out:
# [['정말', '많이', '울다', '영화', '이다'],
#  ['시간', '낭비', '예요'],
#  ['포스터',
#   '를',
#   '저렇게',
#   '밖에',
#   '만들다',
#   '못',
#   '하다',
#   '제작자',
#   '소심하다',
#   '침',
#   '을',
#   '뱉다',
#   '싶다'],
#  ['지금', '보다', '재미있다', '영화', '코믹', '과', '감동', '그리고', '요리']]

# %%
len(clean_test_review)
# Out:
# 11187

# %%
test_sequences = tokenizer.texts_to_sequences(clean_test_review)

# %%
test_inputs = pad_sequences(test_sequences, maxlen=MAX_SEQUENCE_LENGTH, padding='post')  # 테스트 데이터를 벡터화

# %%
preds = model.predict(test_inputs)
preds
# Out:
# array([[0.93011564],
#        [0.01370845],
#        [0.20472167],
#        ...,
#        [0.74226665],
#        [0.94831806],
#        [0.12570806]], dtype=float32)

# %%
start = time.time()  # 시작 시간 저장

test_preds = []
for i, pred in enumerate(preds):
    result = 1 if pred > 0.5 else 0
    test_preds.append(result)
    print(str(i)+"번 인덱스 데이터 처리 완료 =>", pred, test_preds[i])

print("time :", time.time() - start)  # 현재시각 - 시작시간 = 실행 시간
# Out:
# 0번 인덱스 데이터 처리 완료 => [0.93011564] 1
# 1번 인덱스 데이터 처리 완료 => [0.01370845] 0
# 2번 인덱스 데이터 처리 완료 => [0.20472167] 0
# 3번 인덱스 데이터 처리 완료 => [0.992234] 1
# 4번 인덱스 데이터 처리 완료 => [0.27981448] 0
# 5번 인덱스 데이터 처리 완료 => [0.9186513] 1
# 6번 인덱스 데이터 처리 완료 => [0.21725872] 0
# 7번 인덱스 데이터 처리 완료 => [0.62652504] 1
# 8번 인덱스 데이터 처리 완료 => [0.0076016] 0
# 9번 인덱스 데이터 처리 완료 => [0.8279126] 1
# 10번 인덱스 데이터 처리 완료 => [0.9668802] 1
# 11번 인덱스 데이터 처리 완료 => [0.19538935] 0
# 12번 인덱스 데이터 처리 완료 => [0.04017289] 0
# 13번 인덱스 데이터 처리 완료 => [0.20702921] 0
# 14번 인덱스 데이터 처리 완료 => [0.03073664] 0
# 15번 인덱스 데이터 처리 완료 => [0.96021914] 1
# 16번 인덱스 데이터 처리 완료 => [0.562624] 1
# 17번 인덱스 데이터 처리 완료 => [0.8129397] 1
# 18번 인덱스 데이터 처리 완료 => [0.9122772] 1
# 19번 인덱스 데이터 처리 완료 => [0.981434] 1
# 20번 인덱스 데이터 처리 완료 => [0.8053762] 1
# 21번 인덱스 데이터 처리 완료 => [0.9352107] 1
# 22번 인덱스 데이터 처리 완료 => [0.9866196] 1
# 23번 인덱스 데이터 처리 완료 => [0.9363991] 1
# 24번 인덱스 데이터 처리 완료 => [0.19923967] 0
# 25번 인덱스 데이터 처리 완료 => [0.06040347] 0
# 26번 인덱스 데이터 처리 완료 => [0.27987787] 0
# 27번 인덱스 데이터 처리 완료 => [0.18047501] 0
# 28번 인덱스 데이터 처리 완료 => [0.57442635] 1
# 29번 인덱스 데이터 처리 완료 => [0.04648179] 0
# 30번 인덱스 데이터 처리 완료 => [0.83247817] 1
# 31번 인덱스 데이터 처리 완료 => [0.98598945] 1
# 32번 인덱스 데이터 처리 완료 => [0.89358294] 1
# 33번 인덱스 데이터 처리 완료 => [0.21560644] 0
# 34번 인덱스 데이터 처리 완료 => [0.97003585] 1
# 35번 인덱스 데이터 처리 완료 => [0.13456854] 0
# 36번 인덱스 데이터 처리 완료 => [0.22745985] 0
# 37번 인덱스 데이터 처리 완료 => [0.23563309] 0
# 38번 인덱스 데이터 처리 완료 => [0.27094635] 0
# 39번 인덱스 데이터 처리 완료 => [0.45379993] 0
# 40번 인덱스 데이터 처리 완료 => [0.05897428] 0
# 41번 인덱스 데이터 처리 완료 => [0.15024173] 0
# 42번 인덱스 데이터 처리 완료 => [0.1230706] 0
# 43번 인덱스 데이터 처리 완료 => [0.95152193] 1
# 44번 인덱스 데이터 처리 완료 => [0.52408797] 1
# 45번 인덱스 데이터 처리 완료 => [0.17275861] 0
# 46번 인덱스 데이터 처리 완료 => [0.0375441] 0
# 47번 인덱스 데이터 처리 완료 => [0.34675017] 0
# 48번 인덱스 데이터 처리 완료 => [0.01423636] 0
# 49번 인덱스 데이터 처리 완료 => [0.9247561] 1
# 50번 인덱스 데이터 처리 완료 => [0.6526401] 1
# 51번 인덱스 데이터 처리 완료 => [0.574854] 1
# 52번 인덱스 데이터 처리 완료 => [0.02784114] 0
# 53번 인덱스 데이터 처리 완료 => [0.00108647] 0
# 54번 인덱스 데이터 처리 완료 => [0.08915237] 0
# 55번 인덱스 데이터 처리 완료 => [0.10287422] 0
# 56번 인덱스 데이터 처리 완료 => [0.8035225] 1
# 57번 인덱스 데이터 처리 완료 => [0.971086] 1
# 58번 인덱스 데이터 처리 완료 => [0.0413711] 0
# 59번 인덱스 데이터 처리 완료 => [0.04378924] 0
# 60번 인덱스 데이터 처리 완료 => [0.46458027] 0
# 61번 인덱스 데이터 처리 완료 => [0.33437422] 0
# 62번 인덱스 데이터 처리 완료 => [0.80218875] 1
# 63번 인덱스 데이터 처리 완료 => [0.21627042] 0
# 64번 인덱스 데이터 처리 완료 => [0.02717093] 0
# 65번 인덱스 데이터 처리 완료 => [0.00125701] 0
# 66번 인덱스 데이터 처리 완료 => [0.1723621] 0
# 67번 인덱스 데이터 처리 완료 => [0.584524] 1
# 68번 인덱스 데이터 처리 완료 => [0.12244015] 0
# 69번 인덱스 데이터 처리 완료 => [0.14538707] 0
# 70번 인덱스 데이터 처리 완료 => [0.7356539] 1
# 71번 인덱스 데이터 처리 완료 => [0.8043582] 1
# 72번 인덱스 데이터 처리 완료 => [0.68499106] 1
# 73번 인덱스 데이터 처리 완료 => [0.92568636] 1
# 74번 인덱스 데이터 처리 완료 => [0.2991887] 0
# 75번 인덱스 데이터 처리 완료 => [0.22120436] 0
# 76번 인덱스 데이터 처리 완료 => [0.8886438] 1
# 77번 인덱스 데이터 처리 완료 => [0.8432405] 1
# 78번 인덱스 데이터 처리 완료 => [0.7759903] 1
# 79번 인덱스 데이터 처리 완료 => [0.25523937] 0
# 80번 인덱스 데이터 처리 완료 => [0.9638644] 1
# 81번 인덱스 데이터 처리 완료 => [0.95393175] 1
# 82번 인덱스 데이터 처리 완료 => [0.2219909] 0
# 83번 인덱스 데이터 처리 완료 => [0.98293614] 1
# 84번 인덱스 데이터 처리 완료 => [0.9906054] 1
# 85번 인덱스 데이터 처리 완료 => [0.02793878] 0
# 86번 인덱스 데이터 처리 완료 => [0.1887199] 0
# 87번 인덱스 데이터 처리 완료 => [0.29604703] 0
# 88번 인덱스 데이터 처리 완료 => [0.56571656] 1
# 89번 인덱스 데이터 처리 완료 => [0.25016046] 0
# 90번 인덱스 데이터 처리 완료 => [0.7107998] 1
# 91번 인덱스 데이터 처리 완료 => [0.76473975] 1
# 92번 인덱스 데이터 처리 완료 => [0.942229] 1
# 93번 인덱스 데이터 처리 완료 => [0.9680923] 1
# 94번 인덱스 데이터 처리 완료 => [0.4132311] 0
# 95번 인덱스 데이터 처리 완료 => [0.04377007] 0
# 96번 인덱스 데이터 처리 완료 => [0.82855755] 1
# 97번 인덱스 데이터 처리 완료 => [0.98027337] 1
# 98번 인덱스 데이터 처리 완료 => [0.01039443] 0
# 99번 인덱스 데이터 처리 완료 => [0.04804231] 0
# 100번 인덱스 데이터 처리 완료 => [0.0434472] 0
# 101번 인덱스 데이터 처리 완료 => [0.19242927] 0
# 102번 인덱스 데이터 처리 완료 => [0.01891332] 0
# 103번 인덱스 데이터 처리 완료 => [0.03014341] 0
# 104번 인덱스 데이터 처리 완료 => [0.0072512] 0
# 105번 인덱스 데이터 처리 완료 => [0.08078995] 0
# 106번 인덱스 데이터 처리 완료 => [0.8629759] 1
# 107번 인덱스 데이터 처리 완료 => [0.52316445] 1
# 108번 인덱스 데이터 처리 완료 => [0.9780488] 1
# 109번 인덱스 데이터 처리 완료 => [0.34974822] 0
# 110번 인덱스 데이터 처리 완료 => [0.02702378] 0
# 111번 인덱스 데이터 처리 완료 => [0.71223813] 1
# 112번 인덱스 데이터 처리 완료 => [0.9493807] 1
# 113번 인덱스 데이터 처리 완료 => [0.40173444] 0
# 114번 인덱스 데이터 처리 완료 => [0.6006342] 1
# 115번 인덱스 데이터 처리 완료 => [0.69498676] 1
# 116번 인덱스 데이터 처리 완료 => [0.16525748] 0
# 117번 인덱스 데이터 처리 완료 => [0.8908792] 1
# 118번 인덱스 데이터 처리 완료 => [0.01641797] 0
# 119번 인덱스 데이터 처리 완료 => [0.2792041] 0
# 120번 인덱스 데이터 처리 완료 => [0.0177878] 0
# 121번 인덱스 데이터 처리 완료 => [0.86028993] 1
# 122번 인덱스 데이터 처리 완료 => [0.6428179] 1
# 123번 인덱스 데이터 처리 완료 => [0.02340297] 0
# 124번 인덱스 데이터 처리 완료 => [0.9989033] 1
# 125번 인덱스 데이터 처리 완료 => [0.00760682] 0
# 126번 인덱스 데이터 처리 완료 => [0.6257268] 1
# 127번 인덱스 데이터 처리 완료 => [0.5317752] 1
# 128번 인덱스 데이터 처리 완료 => [0.00410325] 0
# 129번 인덱스 데이터 처리 완료 => [0.6177063] 1
# 130번 인덱스 데이터 처리 완료 => [0.8201536] 1
# 131번 인덱스 데이터 처리 완료 => [0.9113935] 1
# 132번 인덱스 데이터 처리 완료 => [0.9707243] 1
# 133번 인덱스 데이터 처리 완료 => [0.09701332] 0
# 134번 인덱스 데이터 처리 완료 => [0.8802508] 1
# 135번 인덱스 데이터 처리 완료 => [0.5985484] 1
# 136번 인덱스 데이터 처리 완료 => [0.25222707] 0
# 137번 인덱스 데이터 처리 완료 => [0.18577765] 0
# 138번 인덱스 데이터 처리 완료 => [0.2512104] 0
# 139번 인덱스 데이터 처리 완료 => [0.96078146] 1
# 140번 인덱스 데이터 처리 완료 => [0.07051292] 0
# 141번 인덱스 데이터 처리 완료 => [0.36701864] 0
# 142번 인덱스 데이터 처리 완료 => [0.95517296] 1
# 143번 인덱스 데이터 처리 완료 => [0.08954578] 0
# 144번 인덱스 데이터 처리 완료 => [0.02240612] 0
# 145번 인덱스 데이터 처리 완료 => [0.5706129] 1
# 146번 인덱스 데이터 처리 완료 => [0.26645315] 0
# 147번 인덱스 데이터 처리 완료 => [0.9743614] 1
# 148번 인덱스 데이터 처리 완료 => [0.8987918] 1
# 149번 인덱스 데이터 처리 완료 => [0.29293236] 0
# 150번 인덱스 데이터 처리 완료 => [0.547959] 1
# 151번 인덱스 데이터 처리 완료 => [0.87029237] 1
# 152번 인덱스 데이터 처리 완료 => [0.8495149] 1
# 153번 인덱스 데이터 처리 완료 => [0.9909372] 1
# 154번 인덱스 데이터 처리 완료 => [0.87737334] 1
# 155번 인덱스 데이터 처리 완료 => [0.74617624] 1
# 156번 인덱스 데이터 처리 완료 => [0.99024755] 1
# 157번 인덱스 데이터 처리 완료 => [0.02029692] 0
# 158번 인덱스 데이터 처리 완료 => [0.0277565] 0
# 159번 인덱스 데이터 처리 완료 => [0.41725963] 0
# 160번 인덱스 데이터 처리 완료 => [0.00926606] 0
# 161번 인덱스 데이터 처리 완료 => [0.86127955] 1
# 162번 인덱스 데이터 처리 완료 => [0.87562746] 1
# 163번 인덱스 데이터 처리 완료 => [0.02249161] 0
# 164번 인덱스 데이터 처리 완료 => [0.09023501] 0
# 165번 인덱스 데이터 처리 완료 => [0.16163363] 0
# 166번 인덱스 데이터 처리 완료 => [0.0807901] 0
# 167번 인덱스 데이터 처리 완료 => [0.547959] 1
# 168번 인덱스 데이터 처리 완료 => [0.04326916] 0
# 169번 인덱스 데이터 처리 완료 => [0.75437355] 1
# 170번 인덱스 데이터 처리 완료 => [0.1274887] 0
# 171번 인덱스 데이터 처리 완료 => [0.9758086] 1
# 172번 인덱스 데이터 처리 완료 => [0.98688567] 1
# 173번 인덱스 데이터 처리 완료 => [0.48527178] 0
# 174번 인덱스 데이터 처리 완료 => [0.3006598] 0
# 175번 인덱스 데이터 처리 완료 => [0.81445557] 1
# 176번 인덱스 데이터 처리 완료 => [0.98895067] 1
# 177번 인덱스 데이터 처리 완료 => [0.65744966] 1
# 178번 인덱스 데이터 처리 완료 => [0.98961747] 1
# 179번 인덱스 데이터 처리 완료 => [0.12522492] 0
# 180번 인덱스 데이터 처리 완료 => [0.02045049] 0
# 181번 인덱스 데이터 처리 완료 => [0.86192346] 1
# 182번 인덱스 데이터 처리 완료 => [0.04133806] 0
# 183번 인덱스 데이터 처리 완료 => [0.93143624] 1
# 184번 인덱스 데이터 처리 완료 => [0.547959] 1
# 185번 인덱스 데이터 처리 완료 => [0.9657845] 1
# 186번 인덱스 데이터 처리 완료 => [0.32468125] 0
# 187번 인덱스 데이터 처리 완료 => [0.96116424] 1
# 188번 인덱스 데이터 처리 완료 => [0.00277973] 0
# 189번 인덱스 데이터 처리 완료 => [0.20922945] 0
# 190번 인덱스 데이터 처리 완료 => [0.94527906] 1
# 191번 인덱스 데이터 처리 완료 => [0.3144773] 0
# 192번 인덱스 데이터 처리 완료 => [0.5551644] 1
# 193번 인덱스 데이터 처리 완료 => [0.547959] 1
# 194번 인덱스 데이터 처리 완료 => [0.01039443] 0
# 195번 인덱스 데이터 처리 완료 => [0.9354784] 1
# 196번 인덱스 데이터 처리 완료 => [0.8876635] 1
# 197번 인덱스 데이터 처리 완료 => [0.13737443] 0
# 198번 인덱스 데이터 처리 완료 => [0.03347798] 0
# 199번 인덱스 데이터 처리 완료 => [0.90892434] 1
# 200번 인덱스 데이터 처리 완료 => [0.46282965] 0
# 201번 인덱스 데이터 처리 완료 => [0.5690349] 1
# 202번 인덱스 데이터 처리 완료 => [0.12765309] 0
# 203번 인덱스 데이터 처리 완료 => [0.02263702] 0
# 204번 인덱스 데이터 처리 완료 => [0.65875024] 1
# 205번 인덱스 데이터 처리 완료 => [0.04112354] 0
# 206번 인덱스 데이터 처리 완료 => [0.89549875] 1
# 207번 인덱스 데이터 처리 완료 => [0.58602816] 1
# 208번 인덱스 데이터 처리 완료 => [0.8224759] 1
# 209번 인덱스 데이터 처리 완료 => [0.8189291] 1
# 210번 인덱스 데이터 처리 완료 => [0.24003932] 0
# 211번 인덱스 데이터 처리 완료 => [0.00630837] 0
# 212번 인덱스 데이터 처리 완료 => [0.7776938] 1
# 213번 인덱스 데이터 처리 완료 => [0.61967003] 1
# 214번 인덱스 데이터 처리 완료 => [0.9850284] 1
# 215번 인덱스 데이터 처리 완료 => [0.25687045] 0
# 216번 인덱스 데이터 처리 완료 => [0.6540919] 1
# 217번 인덱스 데이터 처리 완료 => [0.4559799] 0
# 218번 인덱스 데이터 처리 완료 => [0.48527178] 0
# 219번 인덱스 데이터 처리 완료 => [0.33958048] 0
# 220번 인덱스 데이터 처리 완료 => [0.61881846] 1
# 221번 인덱스 데이터 처리 완료 => [0.6767092] 1
# 222번 인덱스 데이터 처리 완료 => [0.5308183] 1
# 223번 인덱스 데이터 처리 완료 => [0.7565168] 1
# 224번 인덱스 데이터 처리 완료 => [0.8863387] 1
# 225번 인덱스 데이터 처리 완료 => [0.9486991] 1
# 226번 인덱스 데이터 처리 완료 => [0.78378093] 1
# 227번 인덱스 데이터 처리 완료 => [0.94820386] 1
# 228번 인덱스 데이터 처리 완료 => [0.18158242] 0
# 229번 인덱스 데이터 처리 완료 => [0.6589519] 1
# 230번 인덱스 데이터 처리 완료 => [0.7944006] 1
# 231번 인덱스 데이터 처리 완료 => [0.18963417] 0
# 232번 인덱스 데이터 처리 완료 => [0.82276666] 1
# 233번 인덱스 데이터 처리 완료 => [0.3982107] 0
# 234번 인덱스 데이터 처리 완료 => [0.03491696] 0
# 235번 인덱스 데이터 처리 완료 => [0.682455] 1
# 236번 인덱스 데이터 처리 완료 => [0.03941795] 0
# 237번 인덱스 데이터 처리 완료 => [0.888229] 1
# 238번 인덱스 데이터 처리 완료 => [0.96935767] 1
# 239번 인덱스 데이터 처리 완료 => [0.75407314] 1
# 240번 인덱스 데이터 처리 완료 => [0.15384583] 0
# 241번 인덱스 데이터 처리 완료 => [0.4268453] 0
# 242번 인덱스 데이터 처리 완료 => [0.58021003] 1
# 243번 인덱스 데이터 처리 완료 => [0.00619798] 0
# 244번 인덱스 데이터 처리 완료 => [0.82363045] 1
# 245번 인덱스 데이터 처리 완료 => [0.11898433] 0
# 246번 인덱스 데이터 처리 완료 => [0.05153773] 0
# 247번 인덱스 데이터 처리 완료 => [0.93088275] 1
# 248번 인덱스 데이터 처리 완료 => [0.02664323] 0
# 249번 인덱스 데이터 처리 완료 => [0.9476474] 1
# 250번 인덱스 데이터 처리 완료 => [0.96021914] 1
# 251번 인덱스 데이터 처리 완료 => [0.81474185] 1
# 252번 인덱스 데이터 처리 완료 => [0.2748671] 0
# 253번 인덱스 데이터 처리 완료 => [0.7654454] 1
# 254번 인덱스 데이터 처리 완료 => [0.8136827] 1
# 255번 인덱스 데이터 처리 완료 => [0.23578861] 0
# 256번 인덱스 데이터 처리 완료 => [0.353995] 0
# 257번 인덱스 데이터 처리 완료 => [0.76589465] 1
# 258번 인덱스 데이터 처리 완료 => [0.02115998] 0
# 259번 인덱스 데이터 처리 완료 => [0.28351068] 0
# 260번 인덱스 데이터 처리 완료 => [0.9726606] 1
# 261번 인덱스 데이터 처리 완료 => [0.95139664] 1
# 262번 인덱스 데이터 처리 완료 => [0.24682961] 0
# 263번 인덱스 데이터 처리 완료 => [0.16867335] 0
# 264번 인덱스 데이터 처리 완료 => [0.05644151] 0
# 265번 인덱스 데이터 처리 완료 => [0.6337742] 1
# 266번 인덱스 데이터 처리 완료 => [0.67931134] 1
# 267번 인덱스 데이터 처리 완료 => [0.19133297] 0
# 268번 인덱스 데이터 처리 완료 => [0.8993198] 1
# 269번 인덱스 데이터 처리 완료 => [0.3983343] 0
# 270번 인덱스 데이터 처리 완료 => [0.72483045] 1
# 271번 인덱스 데이터 처리 완료 => [0.45893487] 0
# 272번 인덱스 데이터 처리 완료 => [0.49325868] 0
# 273번 인덱스 데이터 처리 완료 => [0.95139664] 1
# 274번 인덱스 데이터 처리 완료 => [0.95139664] 1
# 275번 인덱스 데이터 처리 완료 => [0.9707243] 1
# 276번 인덱스 데이터 처리 완료 => [0.58648455] 1
# 277번 인덱스 데이터 처리 완료 => [0.30286807] 0
# 278번 인덱스 데이터 처리 완료 => [0.0255216] 0
# 279번 인덱스 데이터 처리 완료 => [0.28152156] 0
# 280번 인덱스 데이터 처리 완료 => [0.05710736] 0
# 281번 인덱스 데이터 처리 완료 => [0.6460969] 1
# 282번 인덱스 데이터 처리 완료 => [0.01147769] 0
# 283번 인덱스 데이터 처리 완료 => [0.49891612] 0
# 284번 인덱스 데이터 처리 완료 => [0.00868466] 0
# 285번 인덱스 데이터 처리 완료 => [0.02234548] 0
# 286번 인덱스 데이터 처리 완료 => [0.8528744] 1
# 287번 인덱스 데이터 처리 완료 => [0.07762101] 0
# 288번 인덱스 데이터 처리 완료 => [0.1788035] 0
# 289번 인덱스 데이터 처리 완료 => [0.21419273] 0
# 290번 인덱스 데이터 처리 완료 => [0.24815711] 0
# 291번 인덱스 데이터 처리 완료 => [0.86309] 1
# 292번 인덱스 데이터 처리 완료 => [0.92580205] 1
# 293번 인덱스 데이터 처리 완료 => [0.07040576] 0
# 294번 인덱스 데이터 처리 완료 => [0.9425091] 1
# 295번 인덱스 데이터 처리 완료 => [0.08860966] 0
# 296번 인덱스 데이터 처리 완료 => [0.88698065] 1
# 297번 인덱스 데이터 처리 완료 => [0.9925996] 1
# 298번 인덱스 데이터 처리 완료 => [0.7948878] 1
# 299번 인덱스 데이터 처리 완료 => [0.09357749] 0
# 300번 인덱스 데이터 처리 완료 => [0.98932964] 1
# 301번 인덱스 데이터 처리 완료 => [0.08363272] 0
# 302번 인덱스 데이터 처리 완료 => [0.1064741] 0
# 303번 인덱스 데이터 처리 완료 => [0.00485398] 0
# 304번 인덱스 데이터 처리 완료 => [0.37163496] 0
# 305번 인덱스 데이터 처리 완료 => [0.91466016] 1
# 306번 인덱스 데이터 처리 완료 => [0.5844655] 1
# 307번 인덱스 데이터 처리 완료 => [0.0806685] 0
# 308번 인덱스 데이터 처리 완료 => [0.7772529] 1
# 309번 인덱스 데이터 처리 완료 => [0.9538834] 1
# 310번 인덱스 데이터 처리 완료 => [0.42541125] 0
# 311번 인덱스 데이터 처리 완료 => [0.9603229] 1
# 312번 인덱스 데이터 처리 완료 => [0.22605446] 0
# 313번 인덱스 데이터 처리 완료 => [0.01798273] 0
# 314번 인덱스 데이터 처리 완료 => [0.94941074] 1
# 315번 인덱스 데이터 처리 완료 => [0.00999147] 0
# 316번 인덱스 데이터 처리 완료 => [0.7246712] 1
# 317번 인덱스 데이터 처리 완료 => [0.6883127] 1
# 318번 인덱스 데이터 처리 완료 => [0.86132634] 1
# 319번 인덱스 데이터 처리 완료 => [0.4238179] 0
# 320번 인덱스 데이터 처리 완료 => [0.11228015] 0
# 321번 인덱스 데이터 처리 완료 => [0.01765624] 0
# 322번 인덱스 데이터 처리 완료 => [0.81628567] 1
# 323번 인덱스 데이터 처리 완료 => [0.11560547] 0
# 324번 인덱스 데이터 처리 완료 => [0.9078539] 1
# 325번 인덱스 데이터 처리 완료 => [0.31121922] 0
# 326번 인덱스 데이터 처리 완료 => [0.71341866] 1
# 327번 인덱스 데이터 처리 완료 => [0.28874242] 0
# 328번 인덱스 데이터 처리 완료 => [0.3158927] 0
# 329번 인덱스 데이터 처리 완료 => [0.8709583] 1
# 330번 인덱스 데이터 처리 완료 => [0.2587249] 0
# 331번 인덱스 데이터 처리 완료 => [0.85856515] 1
# 332번 인덱스 데이터 처리 완료 => [0.9746669] 1
# 333번 인덱스 데이터 처리 완료 => [0.93697345] 1
# 334번 인덱스 데이터 처리 완료 => [0.01559896] 0
# 335번 인덱스 데이터 처리 완료 => [0.9644191] 1
# 336번 인덱스 데이터 처리 완료 => [0.45501745] 0
# 337번 인덱스 데이터 처리 완료 => [0.94489026] 1
# 338번 인덱스 데이터 처리 완료 => [0.9009164] 1
# 339번 인덱스 데이터 처리 완료 => [0.6892735] 1
# 340번 인덱스 데이터 처리 완료 => [0.01563043] 0
# 341번 인덱스 데이터 처리 완료 => [0.42290998] 0
# 342번 인덱스 데이터 처리 완료 => [0.9591465] 1
# 343번 인덱스 데이터 처리 완료 => [0.17071487] 0
# 344번 인덱스 데이터 처리 완료 => [0.9172476] 1
# 345번 인덱스 데이터 처리 완료 => [0.00313823] 0
# 346번 인덱스 데이터 처리 완료 => [0.95139664] 1
# 347번 인덱스 데이터 처리 완료 => [0.7658547] 1
# 348번 인덱스 데이터 처리 완료 => [0.6681228] 1
# 349번 인덱스 데이터 처리 완료 => [0.9615071] 1
# 350번 인덱스 데이터 처리 완료 => [0.95232856] 1
# 351번 인덱스 데이터 처리 완료 => [0.18803878] 0
# 352번 인덱스 데이터 처리 완료 => [0.07288007] 0
# 353번 인덱스 데이터 처리 완료 => [0.78554183] 1
# 354번 인덱스 데이터 처리 완료 => [0.9444942] 1
# 355번 인덱스 데이터 처리 완료 => [0.07448663] 0
# 356번 인덱스 데이터 처리 완료 => [0.01824317] 0
# 357번 인덱스 데이터 처리 완료 => [0.98067456] 1
# 358번 인덱스 데이터 처리 완료 => [0.94037473] 1
# 359번 인덱스 데이터 처리 완료 => [0.99446917] 1
# 360번 인덱스 데이터 처리 완료 => [0.96021914] 1
# 361번 인덱스 데이터 처리 완료 => [0.7316027] 1
# 362번 인덱스 데이터 처리 완료 => [0.9906777] 1
# 363번 인덱스 데이터 처리 완료 => [0.9978884] 1
# 364번 인덱스 데이터 처리 완료 => [0.07077727] 0
# 365번 인덱스 데이터 처리 완료 => [0.99654835] 1
# 366번 인덱스 데이터 처리 완료 => [0.02230185] 0
# 367번 인덱스 데이터 처리 완료 => [0.9495226] 1
# 368번 인덱스 데이터 처리 완료 => [0.99022317] 1
# 369번 인덱스 데이터 처리 완료 => [0.88516706] 1
# 370번 인덱스 데이터 처리 완료 => [0.02691588] 0
# 371번 인덱스 데이터 처리 완료 => [0.7543318] 1
# 372번 인덱스 데이터 처리 완료 => [0.1051011] 0
# 373번 인덱스 데이터 처리 완료 => [0.09678699] 0
# 374번 인덱스 데이터 처리 완료 => [0.00145001] 0
# 375번 인덱스 데이터 처리 완료 => [0.547959] 1
# 376번 인덱스 데이터 처리 완료 => [0.8996024] 1
# 377번 인덱스 데이터 처리 완료 => [0.9950063] 1
# 378번 인덱스 데이터 처리 완료 => [0.45761457] 0
# 379번 인덱스 데이터 처리 완료 => [0.5674386] 1
# 380번 인덱스 데이터 처리 완료 => [0.94530636] 1
# 381번 인덱스 데이터 처리 완료 => [0.10202991] 0
# 382번 인덱스 데이터 처리 완료 => [0.99769884] 1
# 383번 인덱스 데이터 처리 완료 => [0.24444585] 0
# 384번 인덱스 데이터 처리 완료 => [0.90510243] 1
# 385번 인덱스 데이터 처리 완료 => [0.9850744] 1
# 386번 인덱스 데이터 처리 완료 => [0.20906977] 0
# 387번 인덱스 데이터 처리 완료 => [0.86364955] 1
# 388번 인덱스 데이터 처리 완료 => [0.13133872] 0
# 389번 인덱스 데이터 처리 완료 => [0.9003527] 1
# 390번 인덱스 데이터 처리 완료 => [0.25769353] 0
# 391번 인덱스 데이터 처리 완료 => [0.5974386] 1
# 392번 인덱스 데이터 처리 완료 => [0.87566227] 1
# 393번 인덱스 데이터 처리 완료 => [0.98930466] 1
# 394번 인덱스 데이터 처리 완료 => [0.837342] 1
# 395번 인덱스 데이터 처리 완료 => [0.9944015] 1
# 396번 인덱스 데이터 처리 완료 => [0.9508436] 1
# 397번 인덱스 데이터 처리 완료 => [0.0200864] 0
# 398번 인덱스 데이터 처리 완료 => [0.9934524] 1
# 399번 인덱스 데이터 처리 완료 => [0.9692635] 1
# 400번 인덱스 데이터 처리 완료 => [0.99761343] 1
# 401번 인덱스 데이터 처리 완료 => [0.35555097] 0
# 402번 인덱스 데이터 처리 완료 => [0.7443262] 1
# 403번 인덱스 데이터 처리 완료 => [0.28831115] 0
# 404번 인덱스 데이터 처리 완료 => [0.36545017] 0
# 405번 인덱스 데이터 처리 완료 => [0.3191371] 0
# 406번 인덱스 데이터 처리 완료 => [0.03826298] 0
# 407번 인덱스 데이터 처리 완료 => [0.979422] 1
# 408번 인덱스 데이터 처리 완료 => [0.78796995] 1
# 409번 인덱스 데이터 처리 완료 => [0.94028723] 1
# 410번 인덱스 데이터 처리 완료 => [0.22968659] 0
# 411번 인덱스 데이터 처리 완료 => [0.05457991] 0
# 412번 인덱스 데이터 처리 완료 => [0.95139664] 1
# 413번 인덱스 데이터 처리 완료 => [0.15038784] 0
# 414번 인덱스 데이터 처리 완료 => [0.38091865] 0
# 415번 인덱스 데이터 처리 완료 => [0.8640134] 1
# 416번 인덱스 데이터 처리 완료 => [0.8857953] 1
# 417번 인덱스 데이터 처리 완료 => [0.8846676] 1
# 418번 인덱스 데이터 처리 완료 => [0.5319373] 1
# 419번 인덱스 데이터 처리 완료 => [0.8102447] 1
# 420번 인덱스 데이터 처리 완료 => [0.9275431] 1
# 421번 인덱스 데이터 처리 완료 => [0.90892434] 1
# 422번 인덱스 데이터 처리 완료 => [0.7006063] 1
# 423번 인덱스 데이터 처리 완료 => [0.0737293] 0
# 424번 인덱스 데이터 처리 완료 => [0.69071543] 1
# 425번 인덱스 데이터 처리 완료 => [0.8816422] 1
# 426번 인덱스 데이터 처리 완료 => [0.9881151] 1
# 427번 인덱스 데이터 처리 완료 => [0.63107866] 1
# 428번 인덱스 데이터 처리 완료 => [0.07245546] 0
# 429번 인덱스 데이터 처리 완료 => [0.71125245] 1
# 430번 인덱스 데이터 처리 완료 => [0.9526511] 1
# 431번 인덱스 데이터 처리 완료 => [0.08451967] 0
# 432번 인덱스 데이터 처리 완료 => [0.03962817] 0
# 433번 인덱스 데이터 처리 완료 => [0.0461504] 0
# 434번 인덱스 데이터 처리 완료 => [0.69415843] 1
# 435번 인덱스 데이터 처리 완료 => [0.7761461] 1
# 436번 인덱스 데이터 처리 완료 => [0.9419517] 1
# 437번 인덱스 데이터 처리 완료 => [0.79435885] 1
# 438번 인덱스 데이터 처리 완료 => [0.34019253] 0
# 439번 인덱스 데이터 처리 완료 => [0.9707243] 1
# 440번 인덱스 데이터 처리 완료 => [0.6038586] 1
# 441번 인덱스 데이터 처리 완료 => [0.48511744] 0
# 442번 인덱스 데이터 처리 완료 => [0.66089445] 1
# 443번 인덱스 데이터 처리 완료 => [0.9962457] 1
# 444번 인덱스 데이터 처리 완료 => [0.12289393] 0
# 445번 인덱스 데이터 처리 완료 => [0.00698872] 0
# 446번 인덱스 데이터 처리 완료 => [0.6515661] 1
# 447번 인덱스 데이터 처리 완료 => [0.9350767] 1
# 448번 인덱스 데이터 처리 완료 => [0.996012] 1
# 449번 인덱스 데이터 처리 완료 => [0.00038054] 0
# 450번 인덱스 데이터 처리 완료 => [0.55280036] 1
# 451번 인덱스 데이터 처리 완료 => [0.06032048] 0
# 452번 인덱스 데이터 처리 완료 => [0.3385787] 0
# 453번 인덱스 데이터 처리 완료 => [0.12648238] 0
# 454번 인덱스 데이터 처리 완료 => [0.11565175] 0
# 455번 인덱스 데이터 처리 완료 => [0.08419741] 0
# 456번 인덱스 데이터 처리 완료 => [0.08653148] 0
# 457번 인덱스 데이터 처리 완료 => [0.72816193] 1
# 458번 인덱스 데이터 처리 완료 => [0.57183987] 1
# 459번 인덱스 데이터 처리 완료 => [0.99527717] 1
# 460번 인덱스 데이터 처리 완료 => [0.48742247] 0
# 461번 인덱스 데이터 처리 완료 => [0.02307512] 0
# 462번 인덱스 데이터 처리 완료 => [0.8818603] 1
# 463번 인덱스 데이터 처리 완료 => [0.63482535] 1
# 464번 인덱스 데이터 처리 완료 => [0.53478724] 1
# 465번 인덱스 데이터 처리 완료 => [0.54264206] 1
# 466번 인덱스 데이터 처리 완료 => [0.37057275] 0
# 467번 인덱스 데이터 처리 완료 => [0.0530655] 0
# 468번 인덱스 데이터 처리 완료 => [0.99120224] 1
# 469번 인덱스 데이터 처리 완료 => [0.53604627] 1
# 470번 인덱스 데이터 처리 완료 => [0.547959] 1
# 471번 인덱스 데이터 처리 완료 => [0.766196] 1
# 472번 인덱스 데이터 처리 완료 => [0.38207287] 0
# 473번 인덱스 데이터 처리 완료 => [0.3294353] 0
# 474번 인덱스 데이터 처리 완료 => [0.7847648] 1
# 475번 인덱스 데이터 처리 완료 => [0.95314324] 1
# 476번 인덱스 데이터 처리 완료 => [0.09905569] 0
# 477번 인덱스 데이터 처리 완료 => [0.7839442] 1
# 478번 인덱스 데이터 처리 완료 => [0.99188167] 1
# 479번 인덱스 데이터 처리 완료 => [0.93303937] 1
# 480번 인덱스 데이터 처리 완료 => [0.5313672] 1
# 481번 인덱스 데이터 처리 완료 => [0.03288207] 0
# 482번 인덱스 데이터 처리 완료 => [0.9716035] 1
# 483번 인덱스 데이터 처리 완료 => [0.99390525] 1
# 484번 인덱스 데이터 처리 완료 => [0.11793029] 0
# 485번 인덱스 데이터 처리 완료 => [0.92364776] 1
# 486번 인덱스 데이터 처리 완료 => [0.5312447] 1
# 487번 인덱스 데이터 처리 완료 => [0.7834995] 1
# 488번 인덱스 데이터 처리 완료 => [0.15389077] 0
# 489번 인덱스 데이터 처리 완료 => [0.10313266] 0
# 490번 인덱스 데이터 처리 완료 => [0.8978032] 1
# 491번 인덱스 데이터 처리 완료 => [0.90398955] 1
# 492번 인덱스 데이터 처리 완료 => [0.92122465] 1
# 493번 인덱스 데이터 처리 완료 => [0.03083873] 0
# 494번 인덱스 데이터 처리 완료 => [0.06191507] 0
# 495번 인덱스 데이터 처리 완료 => [0.5519722] 1
# 496번 인덱스 데이터 처리 완료 => [0.16913025] 0
# 497번 인덱스 데이터 처리 완료 => [0.00615589] 0
# 498번 인덱스 데이터 처리 완료 => [0.4792811] 0
# 499번 인덱스 데이터 처리 완료 => [0.86454827] 1
# 500번 인덱스 데이터 처리 완료 => [0.998931] 1
# 501번 인덱스 데이터 처리 완료 => [0.2326033] 0
# 502번 인덱스 데이터 처리 완료 => [0.1931869] 0
# 503번 인덱스 데이터 처리 완료 => [0.21205729] 0
# 504번 인덱스 데이터 처리 완료 => [0.14736448] 0
# 505번 인덱스 데이터 처리 완료 => [0.33814773] 0
# 506번 인덱스 데이터 처리 완료 => [0.3613463] 0
# 507번 인덱스 데이터 처리 완료 => [0.9244297] 1
# 508번 인덱스 데이터 처리 완료 => [0.05557251] 0
# 509번 인덱스 데이터 처리 완료 => [0.03071027] 0
# 510번 인덱스 데이터 처리 완료 => [0.893688] 1
# 511번 인덱스 데이터 처리 완료 => [0.9243912] 1
# 512번 인덱스 데이터 처리 완료 => [0.8404798] 1
# 513번 인덱스 데이터 처리 완료 => [0.8669907] 1
# 514번 인덱스 데이터 처리 완료 => [0.12662025] 0
# 515번 인덱스 데이터 처리 완료 => [0.0633378] 0
# 516번 인덱스 데이터 처리 완료 => [0.76837724] 1
# 517번 인덱스 데이터 처리 완료 => [0.2526033] 0
# 518번 인덱스 데이터 처리 완료 => [0.8704724] 1
# 519번 인덱스 데이터 처리 완료 => [0.65309864] 1
# 520번 인덱스 데이터 처리 완료 => [0.87128913] 1
# 521번 인덱스 데이터 처리 완료 => [0.7836404] 1
# 522번 인덱스 데이터 처리 완료 => [0.99549377] 1
# 523번 인덱스 데이터 처리 완료 => [0.9164708] 1
# 524번 인덱스 데이터 처리 완료 => [0.70666] 1
# 525번 인덱스 데이터 처리 완료 => [0.03964463] 0
# 526번 인덱스 데이터 처리 완료 => [0.80403775] 1
# 527번 인덱스 데이터 처리 완료 => [0.64813644] 1
# 528번 인덱스 데이터 처리 완료 => [0.07501301] 0
# 529번 인덱스 데이터 처리 완료 => [0.65925246] 1
# 530번 인덱스 데이터 처리 완료 => [0.8931277] 1
# 531번 인덱스 데이터 처리 완료 => [0.770134] 1
# 532번 인덱스 데이터 처리 완료 => [0.6057509] 1
# 533번 인덱스 데이터 처리 완료 => [0.8098011] 1
# 534번 인덱스 데이터 처리 완료 => [0.81208104] 1
# 535번 인덱스 데이터 처리 완료 => [0.7970586] 1
# 536번 인덱스 데이터 처리 완료 => [0.11242145] 0
# 537번 인덱스 데이터 처리 완료 => [0.39506695] 0
# 538번 인덱스 데이터 처리 완료 => [0.7215688] 1
# 539번 인덱스 데이터 처리 완료 => [0.09993835] 0
# 540번 인덱스 데이터 처리 완료 => [0.06521048] 0
# 541번 인덱스 데이터 처리 완료 => [0.942229] 1
# 542번 인덱스 데이터 처리 완료 => [0.9112619] 1
# 543번 인덱스 데이터 처리 완료 => [0.98608613] 1
# 544번 인덱스 데이터 처리 완료 => [0.54971194] 1
# 545번 인덱스 데이터 처리 완료 => [0.01129622] 0
# 546번 인덱스 데이터 처리 완료 => [0.40978128] 0
# 547번 인덱스 데이터 처리 완료 => [0.5803713] 1
# 548번 인덱스 데이터 처리 완료 => [0.28350237] 0
# 549번 인덱스 데이터 처리 완료 => [0.40959424] 0
# 550번 인덱스 데이터 처리 완료 => [0.94355863] 1
# 551번 인덱스 데이터 처리 완료 => [0.9716733] 1
# 552번 인덱스 데이터 처리 완료 => [0.24049227] 0
# 553번 인덱스 데이터 처리 완료 => [0.909212] 1
# 554번 인덱스 데이터 처리 완료 => [0.12704572] 0
# 555번 인덱스 데이터 처리 완료 => [0.08035216] 0
# 556번 인덱스 데이터 처리 완료 => [0.81083107] 1
# 557번 인덱스 데이터 처리 완료 => [0.9983847] 1
# 558번 인덱스 데이터 처리 완료 => [0.6883607] 1
# 559번 인덱스 데이터 처리 완료 => [0.46793535] 0
# 560번 인덱스 데이터 처리 완료 => [0.12862362] 0
# 561번 인덱스 데이터 처리 완료 => [0.03423919] 0
# 562번 인덱스 데이터 처리 완료 => [0.9357058] 1
# 563번 인덱스 데이터 처리 완료 => [0.95813894] 1
# 564번 인덱스 데이터 처리 완료 => [0.9171858] 1
# 565번 인덱스 데이터 처리 완료 => [0.00674003] 0
# 566번 인덱스 데이터 처리 완료 => [0.0169809] 0
# 567번 인덱스 데이터 처리 완료 => [0.9104738] 1
# 568번 인덱스 데이터 처리 완료 => [0.04974925] 0
# 569번 인덱스 데이터 처리 완료 => [0.01455777] 0
# 570번 인덱스 데이터 처리 완료 => [0.7951215] 1
# 571번 인덱스 데이터 처리 완료 => [0.7969074] 1
# 572번 인덱스 데이터 처리 완료 => [0.73865336] 1
# 573번 인덱스 데이터 처리 완료 => [0.9998648] 1
# 574번 인덱스 데이터 처리 완료 => [0.9615837] 1
# 575번 인덱스 데이터 처리 완료 => [0.37406045] 0
# 576번 인덱스 데이터 처리 완료 => [0.09424549] 0
# 577번 인덱스 데이터 처리 완료 => [0.9652323] 1
# 578번 인덱스 데이터 처리 완료 => [0.74566805] 1
# 579번 인덱스 데이터 처리 완료 => [0.9751456] 1
# 580번 인덱스 데이터 처리 완료 => [0.14953783] 0
# 581번 인덱스 데이터 처리 완료 => [0.7972789] 1
# 582번 인덱스 데이터 처리 완료 => [0.9716733] 1
# 583번 인덱스 데이터 처리 완료 => [0.06127938] 0
# 584번 인덱스 데이터 처리 완료 => [0.23071228] 0
# 585번 인덱스 데이터 처리 완료 => [0.84998715] 1
# 586번 인덱스 데이터 처리 완료 => [0.41152194] 0
# 587번 인덱스 데이터 처리 완료 => [0.9805597] 1
# 588번 인덱스 데이터 처리 완료 => [0.04921396] 0
# 589번 인덱스 데이터 처리 완료 => [0.0432883] 0
# 590번 인덱스 데이터 처리 완료 => [0.0810472] 0
# 591번 인덱스 데이터 처리 완료 => [0.0810472] 0
# 592번 인덱스 데이터 처리 완료 => [0.96021914] 1
# 593번 인덱스 데이터 처리 완료 => [0.6110801] 1
# 594번 인덱스 데이터 처리 완료 => [0.9011123] 1
# 595번 인덱스 데이터 처리 완료 => [0.04032918] 0
# 596번 인덱스 데이터 처리 완료 => [0.86517984] 1
# 597번 인덱스 데이터 처리 완료 => [0.00263134] 0
# 598번 인덱스 데이터 처리 완료 => [0.2202688] 0
# 599번 인덱스 데이터 처리 완료 => [0.09576966] 0
# 600번 인덱스 데이터 처리 완료 => [0.40358174] 0
# 601번 인덱스 데이터 처리 완료 => [0.46149543] 0
# 602번 인덱스 데이터 처리 완료 => [0.9418697] 1
# 603번 인덱스 데이터 처리 완료 => [0.97761256] 1
# 604번 인덱스 데이터 처리 완료 => [0.13252732] 0
# 605번 인덱스 데이터 처리 완료 => [0.609036] 1
# 606번 인덱스 데이터 처리 완료 => [0.5503218] 1
# 607번 인덱스 데이터 처리 완료 => [0.8946102] 1
# 608번 인덱스 데이터 처리 완료 => [0.99455124] 1
# 609번 인덱스 데이터 처리 완료 => [0.07155125] 0
# 610번 인덱스 데이터 처리 완료 => [0.10910698] 0
# 611번 인덱스 데이터 처리 완료 => [0.0005522] 0
# 612번 인덱스 데이터 처리 완료 => [0.9956852] 1
# 613번 인덱스 데이터 처리 완료 => [0.05817252] 0
# 614번 인덱스 데이터 처리 완료 => [0.11127704] 0
# 615번 인덱스 데이터 처리 완료 => [0.00485398] 0
# 616번 인덱스 데이터 처리 완료 => [0.08789192] 0
# 617번 인덱스 데이터 처리 완료 => [0.7361552] 1
# 618번 인덱스 데이터 처리 완료 => [0.1802727] 0
# 619번 인덱스 데이터 처리 완료 => [0.8600055] 1
# 620번 인덱스 데이터 처리 완료 => [0.9618455] 1
# 621번 인덱스 데이터 처리 완료 => [0.86052537] 1
# 622번 인덱스 데이터 처리 완료 => [0.5882259] 1
# 623번 인덱스 데이터 처리 완료 => [0.9189568] 1
# 624번 인덱스 데이터 처리 완료 => [0.985137] 1
# 625번 인덱스 데이터 처리 완료 => [0.16101508] 0
# 626번 인덱스 데이터 처리 완료 => [0.185189] 0
# 627번 인덱스 데이터 처리 완료 => [0.9760953] 1
# 628번 인덱스 데이터 처리 완료 => [0.30635166] 0
# 629번 인덱스 데이터 처리 완료 => [0.9904372] 1
# 630번 인덱스 데이터 처리 완료 => [0.05564489] 0
# 631번 인덱스 데이터 처리 완료 => [0.8620922] 1
# 632번 인덱스 데이터 처리 완료 => [0.37576416] 0
# 633번 인덱스 데이터 처리 완료 => [0.5482191] 1
# 634번 인덱스 데이터 처리 완료 => [0.3353122] 0
# 635번 인덱스 데이터 처리 완료 => [0.5289944] 1
# 636번 인덱스 데이터 처리 완료 => [0.7092804] 1
# 637번 인덱스 데이터 처리 완료 => [0.547959] 1
# 638번 인덱스 데이터 처리 완료 => [0.06958518] 0
# 639번 인덱스 데이터 처리 완료 => [0.5350487] 1
# 640번 인덱스 데이터 처리 완료 => [0.942229] 1
# 641번 인덱스 데이터 처리 완료 => [0.08112709] 0
# 642번 인덱스 데이터 처리 완료 => [0.7681147] 1
# 643번 인덱스 데이터 처리 완료 => [0.13308784] 0
# 644번 인덱스 데이터 처리 완료 => [0.0177878] 0
# 645번 인덱스 데이터 처리 완료 => [0.9961422] 1
# 646번 인덱스 데이터 처리 완료 => [0.683052] 1
# 647번 인덱스 데이터 처리 완료 => [0.47639418] 0
# 648번 인덱스 데이터 처리 완료 => [0.7711092] 1
# 649번 인덱스 데이터 처리 완료 => [0.8988023] 1
# 650번 인덱스 데이터 처리 완료 => [0.952131] 1
# 651번 인덱스 데이터 처리 완료 => [0.5468378] 1
# 652번 인덱스 데이터 처리 완료 => [0.40617836] 0
# 653번 인덱스 데이터 처리 완료 => [0.9869446] 1
# 654번 인덱스 데이터 처리 완료 => [0.6735235] 1
# 655번 인덱스 데이터 처리 완료 => [0.13286172] 0
# 656번 인덱스 데이터 처리 완료 => [0.92844146] 1
# 657번 인덱스 데이터 처리 완료 => [0.05978392] 0
# 658번 인덱스 데이터 처리 완료 => [0.73717797] 1
# 659번 인덱스 데이터 처리 완료 => [0.00348596] 0
# 660번 인덱스 데이터 처리 완료 => [0.02584681] 0
# 661번 인덱스 데이터 처리 완료 => [0.898933] 1
# 662번 인덱스 데이터 처리 완료 => [0.7389444] 1
# 663번 인덱스 데이터 처리 완료 => [0.99260616] 1
# 664번 인덱스 데이터 처리 완료 => [0.18701768] 0
# 665번 인덱스 데이터 처리 완료 => [0.6337319] 1
# 666번 인덱스 데이터 처리 완료 => [0.9302426] 1
# 667번 인덱스 데이터 처리 완료 => [0.06332888] 0
# 668번 인덱스 데이터 처리 완료 => [0.5499203] 1
# 669번 인덱스 데이터 처리 완료 => [0.4803673] 0
# 670번 인덱스 데이터 처리 완료 => [0.03415319] 0
# 671번 인덱스 데이터 처리 완료 => [0.99293] 1
# 672번 인덱스 데이터 처리 완료 => [0.84548205] 1
# 673번 인덱스 데이터 처리 완료 => [0.99719185] 1
# 674번 인덱스 데이터 처리 완료 => [0.03347115] 0
# 675번 인덱스 데이터 처리 완료 => [0.956253] 1
# 676번 인덱스 데이터 처리 완료 => [0.662382] 1
# 677번 인덱스 데이터 처리 완료 => [0.09416826] 0
# 678번 인덱스 데이터 처리 완료 => [0.36587846] 0
# 679번 인덱스 데이터 처리 완료 => [0.08529412] 0
# 680번 인덱스 데이터 처리 완료 => [0.08444882] 0
# 681번 인덱스 데이터 처리 완료 => [0.3861017] 0
# 682번 인덱스 데이터 처리 완료 => [0.8407195] 1
# 683번 인덱스 데이터 처리 완료 => [0.36646813] 0
# 684번 인덱스 데이터 처리 완료 => [0.3738209] 0
# 685번 인덱스 데이터 처리 완료 => [0.04037469] 0
# 686번 인덱스 데이터 처리 완료 => [0.41175747] 0
# 687번 인덱스 데이터 처리 완료 => [0.83501154] 1
# 688번 인덱스 데이터 처리 완료 => [0.6923732] 1
# 689번 인덱스 데이터 처리 완료 => [0.63063455] 1
# 690번 인덱스 데이터 처리 완료 => [0.43223414] 0
# 691번 인덱스 데이터 처리 완료 => [0.87393594] 1
# 692번 인덱스 데이터 처리 완료 => [0.59888345] 1
# 693번 인덱스 데이터 처리 완료 => [0.9658085] 1
# 694번 인덱스 데이터 처리 완료 => [0.49416482] 0
# 695번 인덱스 데이터 처리 완료 => [0.13724488] 0
# 696번 인덱스 데이터 처리 완료 => [0.34874654] 0
# 697번 인덱스 데이터 처리 완료 => [0.8531688] 1
# 698번 인덱스 데이터 처리 완료 => [0.5548876] 1
# 699번 인덱스 데이터 처리 완료 => [0.03389707] 0
# 700번 인덱스 데이터 처리 완료 => [0.32777473] 0
# 701번 인덱스 데이터 처리 완료 => [0.85059667] 1
# 702번 인덱스 데이터 처리 완료 => [0.00320705] 0
# 703번 인덱스 데이터 처리 완료 => [0.10168678] 0
# 704번 인덱스 데이터 처리 완료 => [0.4916545] 0
# 705번 인덱스 데이터 처리 완료 => [0.36969927] 0
# 706번 인덱스 데이터 처리 완료 => [0.4674298] 0
# 707번 인덱스 데이터 처리 완료 => [0.0236559] 0
# 708번 인덱스 데이터 처리 완료 => [0.07815845] 0
# 709번 인덱스 데이터 처리 완료 => [0.5432614] 1
# 710번 인덱스 데이터 처리 완료 => [0.20705524] 0
# 711번 인덱스 데이터 처리 완료 => [0.77681345] 1
# 712번 인덱스 데이터 처리 완료 => [0.21477565] 0
# 713번 인덱스 데이터 처리 완료 => [0.6304733] 1
# 714번 인덱스 데이터 처리 완료 => [0.05552889] 0
# 715번 인덱스 데이터 처리 완료 => [0.9865232] 1
# 716번 인덱스 데이터 처리 완료 => [0.05620484] 0
# 717번 인덱스 데이터 처리 완료 => [0.23850922] 0
# 718번 인덱스 데이터 처리 완료 => [0.9960632] 1
# 719번 인덱스 데이터 처리 완료 => [0.87523735] 1
# 720번 인덱스 데이터 처리 완료 => [0.9707243] 1
# 721번 인덱스 데이터 처리 완료 => [0.05227093] 0
# 722번 인덱스 데이터 처리 완료 => [0.9972402] 1
# 723번 인덱스 데이터 처리 완료 => [0.0552278] 0
# 724번 인덱스 데이터 처리 완료 => [0.9725257] 1
# 725번 인덱스 데이터 처리 완료 => [0.87566227] 1
# 726번 인덱스 데이터 처리 완료 => [0.3497924] 0
# 727번 인덱스 데이터 처리 완료 => [0.21608157] 0
# 728번 인덱스 데이터 처리 완료 => [0.932014] 1
# 729번 인덱스 데이터 처리 완료 => [0.99973017] 1
# 730번 인덱스 데이터 처리 완료 => [0.64879024] 1
# 731번 인덱스 데이터 처리 완료 => [0.69498676] 1
# 732번 인덱스 데이터 처리 완료 => [0.942229] 1
# 733번 인덱스 데이터 처리 완료 => [0.8805533] 1
# 734번 인덱스 데이터 처리 완료 => [0.81641906] 1
# 735번 인덱스 데이터 처리 완료 => [0.10264163] 0
# 736번 인덱스 데이터 처리 완료 => [0.50805503] 1
# 737번 인덱스 데이터 처리 완료 => [0.8913568] 1
# 738번 인덱스 데이터 처리 완료 => [0.9179693] 1
# 739번 인덱스 데이터 처리 완료 => [0.5248842] 1
# 740번 인덱스 데이터 처리 완료 => [0.0014754] 0
# 741번 인덱스 데이터 처리 완료 => [0.11527596] 0
# 742번 인덱스 데이터 처리 완료 => [0.98437554] 1
# 743번 인덱스 데이터 처리 완료 => [0.6511194] 1
# 744번 인덱스 데이터 처리 완료 => [0.36446336] 0
# 745번 인덱스 데이터 처리 완료 => [0.93265295] 1
# 746번 인덱스 데이터 처리 완료 => [0.9938829] 1
# 747번 인덱스 데이터 처리 완료 => [0.82478756] 1
# 748번 인덱스 데이터 처리 완료 => [0.99100363] 1
# 749번 인덱스 데이터 처리 완료 => [0.74173653] 1
# 750번 인덱스 데이터 처리 완료 => [0.03193929] 0
# 751번 인덱스 데이터 처리 완료 => [0.40572903] 0
# 752번 인덱스 데이터 처리 완료 => [0.9708236] 1
# 753번 인덱스 데이터 처리 완료 => [0.00449323] 0
# 754번 인덱스 데이터 처리 완료 => [0.92333966] 1
# 755번 인덱스 데이터 처리 완료 => [0.43749] 0
# 756번 인덱스 데이터 처리 완료 => [0.1604018] 0
# 757번 인덱스 데이터 처리 완료 => [0.00172] 0
# 758번 인덱스 데이터 처리 완료 => [0.8859233] 1
# 759번 인덱스 데이터 처리 완료 => [0.30026588] 0
# 760번 인덱스 데이터 처리 완료 => [0.0248352] 0
# 761번 인덱스 데이터 처리 완료 => [0.81847024] 1
# 762번 인덱스 데이터 처리 완료 => [0.15221071] 0
# 763번 인덱스 데이터 처리 완료 => [0.5481267] 1
# 764번 인덱스 데이터 처리 완료 => [0.87134165] 1
# 765번 인덱스 데이터 처리 완료 => [0.00616998] 0
# 766번 인덱스 데이터 처리 완료 => [0.60020506] 1
# 767번 인덱스 데이터 처리 완료 => [0.9984768] 1
# 768번 인덱스 데이터 처리 완료 => [0.5472693] 1
# 769번 인덱스 데이터 처리 완료 => [0.39638722] 0
# 770번 인덱스 데이터 처리 완료 => [0.14091676] 0
# 771번 인덱스 데이터 처리 완료 => [0.9619457] 1
# 772번 인덱스 데이터 처리 완료 => [0.72701037] 1
# 773번 인덱스 데이터 처리 완료 => [0.6675575] 1
# 774번 인덱스 데이터 처리 완료 => [0.9548608] 1
# 775번 인덱스 데이터 처리 완료 => [0.09209086] 0
# 776번 인덱스 데이터 처리 완료 => [0.7694649] 1
# 777번 인덱스 데이터 처리 완료 => [0.18996525] 0
# 778번 인덱스 데이터 처리 완료 => [0.35419485] 0
# 779번 인덱스 데이터 처리 완료 => [0.00793157] 0
# 780번 인덱스 데이터 처리 완료 => [0.2929212] 0
# 781번 인덱스 데이터 처리 완료 => [0.3762955] 0
# 782번 인덱스 데이터 처리 완료 => [0.1407747] 0
# 783번 인덱스 데이터 처리 완료 => [0.00470538] 0
# 784번 인덱스 데이터 처리 완료 => [0.52069783] 1
# 785번 인덱스 데이터 처리 완료 => [0.24654585] 0
# 786번 인덱스 데이터 처리 완료 => [0.91539615] 1
# 787번 인덱스 데이터 처리 완료 => [0.40352988] 0
# 788번 인덱스 데이터 처리 완료 => [0.4634623] 0
# 789번 인덱스 데이터 처리 완료 => [0.56172186] 1
# 790번 인덱스 데이터 처리 완료 => [0.00970408] 0
# 791번 인덱스 데이터 처리 완료 => [0.9902801] 1
# 792번 인덱스 데이터 처리 완료 => [0.00974091] 0
# 793번 인덱스 데이터 처리 완료 => [0.98312855] 1
# 794번 인덱스 데이터 처리 완료 => [0.9862455] 1
# 795번 인덱스 데이터 처리 완료 => [0.8605155] 1
# 796번 인덱스 데이터 처리 완료 => [0.9990633] 1
# 797번 인덱스 데이터 처리 완료 => [0.23806176] 0
# 798번 인덱스 데이터 처리 완료 => [0.7183233] 1
# 799번 인덱스 데이터 처리 완료 => [0.08689687] 0
# 800번 인덱스 데이터 처리 완료 => [0.11353203] 0
# 801번 인덱스 데이터 처리 완료 => [0.41521654] 0
# 802번 인덱스 데이터 처리 완료 => [0.9562434] 1
# 803번 인덱스 데이터 처리 완료 => [0.08916858] 0
# 804번 인덱스 데이터 처리 완료 => [0.51201373] 1
# 805번 인덱스 데이터 처리 완료 => [0.489321] 0
# 806번 인덱스 데이터 처리 완료 => [0.30974513] 0
# 807번 인덱스 데이터 처리 완료 => [0.62587523] 1
# 808번 인덱스 데이터 처리 완료 => [0.12843384] 0
# 809번 인덱스 데이터 처리 완료 => [0.9089407] 1
# 810번 인덱스 데이터 처리 완료 => [0.20811455] 0
# 811번 인덱스 데이터 처리 완료 => [0.99986446] 1
# 812번 인덱스 데이터 처리 완료 => [0.95139664] 1
# 813번 인덱스 데이터 처리 완료 => [0.8665657] 1
# 814번 인덱스 데이터 처리 완료 => [0.11468822] 0
# 815번 인덱스 데이터 처리 완료 => [0.48354745] 0
# 816번 인덱스 데이터 처리 완료 => [0.9873497] 1
# 817번 인덱스 데이터 처리 완료 => [0.61554384] 1
# 818번 인덱스 데이터 처리 완료 => [0.09279072] 0
# 819번 인덱스 데이터 처리 완료 => [0.3661268] 0
# 820번 인덱스 데이터 처리 완료 => [0.42297524] 0
# 821번 인덱스 데이터 처리 완료 => [0.5563213] 1
# 822번 인덱스 데이터 처리 완료 => [0.14743082] 0
# 823번 인덱스 데이터 처리 완료 => [0.524099] 1
# 824번 인덱스 데이터 처리 완료 => [0.0305314] 0
# 825번 인덱스 데이터 처리 완료 => [0.16995086] 0
# 826번 인덱스 데이터 처리 완료 => [0.8384822] 1
# 827번 인덱스 데이터 처리 완료 => [0.90431905] 1
# 828번 인덱스 데이터 처리 완료 => [0.9716733] 1
# 829번 인덱스 데이터 처리 완료 => [0.98914903] 1
# 830번 인덱스 데이터 처리 완료 => [0.5515076] 1
# 831번 인덱스 데이터 처리 완료 => [0.779021] 1
# 832번 인덱스 데이터 처리 완료 => [0.8939705] 1
# 833번 인덱스 데이터 처리 완료 => [0.29152852] 0
# 834번 인덱스 데이터 처리 완료 => [0.82457036] 1
# 835번 인덱스 데이터 처리 완료 => [0.19564658] 0
# 836번 인덱스 데이터 처리 완료 => [0.4820286] 0
# 837번 인덱스 데이터 처리 완료 => [0.68718743] 1
# 838번 인덱스 데이터 처리 완료 => [0.09701332] 0
# 839번 인덱스 데이터 처리 완료 => [0.9892848] 1
# 840번 인덱스 데이터 처리 완료 => [0.02528299] 0
# 841번 인덱스 데이터 처리 완료 => [0.9162716] 1
# 842번 인덱스 데이터 처리 완료 => [0.39955392] 0
# 843번 인덱스 데이터 처리 완료 => [0.31815952] 0
# 844번 인덱스 데이터 처리 완료 => [0.59129584] 1
# 845번 인덱스 데이터 처리 완료 => [0.70014316] 1
# 846번 인덱스 데이터 처리 완료 => [0.6006342] 1
# 847번 인덱스 데이터 처리 완료 => [0.9780604] 1
# 848번 인덱스 데이터 처리 완료 => [0.02754371] 0
# 849번 인덱스 데이터 처리 완료 => [0.8822906] 1
# 850번 인덱스 데이터 처리 완료 => [0.94690394] 1
# 851번 인덱스 데이터 처리 완료 => [0.9711728] 1
# 852번 인덱스 데이터 처리 완료 => [0.16108696] 0
# 853번 인덱스 데이터 처리 완료 => [0.7217296] 1
# 854번 인덱스 데이터 처리 완료 => [0.24458829] 0
# 855번 인덱스 데이터 처리 완료 => [0.9710127] 1
# 856번 인덱스 데이터 처리 완료 => [0.92682236] 1
# 857번 인덱스 데이터 처리 완료 => [0.97222286] 1
# 858번 인덱스 데이터 처리 완료 => [0.01191335] 0
# 859번 인덱스 데이터 처리 완료 => [0.9683906] 1
# 860번 인덱스 데이터 처리 완료 => [0.962523] 1
# 861번 인덱스 데이터 처리 완료 => [0.37407252] 0
# 862번 인덱스 데이터 처리 완료 => [0.34370688] 0
# 863번 인덱스 데이터 처리 완료 => [0.84516567] 1
# 864번 인덱스 데이터 처리 완료 => [0.00945479] 0
# 865번 인덱스 데이터 처리 완료 => [0.89657] 1
# 866번 인덱스 데이터 처리 완료 => [0.40915337] 0
# 867번 인덱스 데이터 처리 완료 => [0.3016995] 0
# 868번 인덱스 데이터 처리 완료 => [0.7081643] 1
# 869번 인덱스 데이터 처리 완료 => [0.19431631] 0
# 870번 인덱스 데이터 처리 완료 => [0.7844188] 1
# 871번 인덱스 데이터 처리 완료 => [0.7507162] 1
# 872번 인덱스 데이터 처리 완료 => [0.6398481] 1
# 873번 인덱스 데이터 처리 완료 => [0.49571276] 0
# 874번 인덱스 데이터 처리 완료 => [0.9698352] 1
# 875번 인덱스 데이터 처리 완료 => [0.547959] 1
# 876번 인덱스 데이터 처리 완료 => [0.06332888] 0
# 877번 인덱스 데이터 처리 완료 => [0.39214438] 0
# 878번 인덱스 데이터 처리 완료 => [0.13836132] 0
# 879번 인덱스 데이터 처리 완료 => [0.547959] 1
# 880번 인덱스 데이터 처리 완료 => [0.42953467] 0
# 881번 인덱스 데이터 처리 완료 => [0.547959] 1
# 882번 인덱스 데이터 처리 완료 => [0.21066344] 0
# 883번 인덱스 데이터 처리 완료 => [0.54134554] 1
# 884번 인덱스 데이터 처리 완료 => [0.8898022] 1
# 885번 인덱스 데이터 처리 완료 => [0.18089344] 0
# 886번 인덱스 데이터 처리 완료 => [0.9108764] 1
# 887번 인덱스 데이터 처리 완료 => [0.9480471] 1
# 888번 인덱스 데이터 처리 완료 => [0.43005967] 0
# 889번 인덱스 데이터 처리 완료 => [0.42329723] 0
# 890번 인덱스 데이터 처리 완료 => [0.9556706] 1
# 891번 인덱스 데이터 처리 완료 => [0.26547113] 0
# 892번 인덱스 데이터 처리 완료 => [0.06831761] 0
# 893번 인덱스 데이터 처리 완료 => [0.7970488] 1
# 894번 인덱스 데이터 처리 완료 => [0.02982907] 0
# 895번 인덱스 데이터 처리 완료 => [0.10679985] 0
# 896번 인덱스 데이터 처리 완료 => [0.9949824] 1
# 897번 인덱스 데이터 처리 완료 => [0.02130925] 0
# 898번 인덱스 데이터 처리 완료 => [0.9365398] 1
# 899번 인덱스 데이터 처리 완료 => [0.0375436] 0
# 900번 인덱스 데이터 처리 완료 => [0.82331026] 1
# 901번 인덱스 데이터 처리 완료 => [0.22846441] 0
# 902번 인덱스 데이터 처리 완료 => [0.06148034] 0
# 903번 인덱스 데이터 처리 완료 => [0.83298755] 1
# 904번 인덱스 데이터 처리 완료 => [0.3725624] 0
# 905번 인덱스 데이터 처리 완료 => [0.324294] 0
# 906번 인덱스 데이터 처리 완료 => [0.29816958] 0
# 907번 인덱스 데이터 처리 완료 => [0.71744347] 1
# 908번 인덱스 데이터 처리 완료 => [0.8988568] 1
# 909번 인덱스 데이터 처리 완료 => [0.13827483] 0
# 910번 인덱스 데이터 처리 완료 => [0.97913647] 1
# 911번 인덱스 데이터 처리 완료 => [0.25376114] 0
# 912번 인덱스 데이터 처리 완료 => [0.377553] 0
# 913번 인덱스 데이터 처리 완료 => [0.547959] 1
# 914번 인덱스 데이터 처리 완료 => [0.39880282] 0
# 915번 인덱스 데이터 처리 완료 => [0.8183693] 1
# 916번 인덱스 데이터 처리 완료 => [0.9702517] 1
# 917번 인덱스 데이터 처리 완료 => [0.85111827] 1
# 918번 인덱스 데이터 처리 완료 => [0.9998362] 1
# 919번 인덱스 데이터 처리 완료 => [0.9243912] 1
# 920번 인덱스 데이터 처리 완료 => [0.26026705] 0
# 921번 인덱스 데이터 처리 완료 => [0.38747945] 0
# 922번 인덱스 데이터 처리 완료 => [0.8394822] 1
# 923번 인덱스 데이터 처리 완료 => [0.60310805] 1
# 924번 인덱스 데이터 처리 완료 => [0.4344367] 0
# 925번 인덱스 데이터 처리 완료 => [0.02749054] 0
# 926번 인덱스 데이터 처리 완료 => [0.87566227] 1
# 927번 인덱스 데이터 처리 완료 => [0.07736506] 0
# 928번 인덱스 데이터 처리 완료 => [0.011729] 0
# 929번 인덱스 데이터 처리 완료 => [0.7165047] 1
# 930번 인덱스 데이터 처리 완료 => [0.831763] 1
# 931번 인덱스 데이터 처리 완료 => [0.6145264] 1
# 932번 인덱스 데이터 처리 완료 => [0.8823065] 1
# 933번 인덱스 데이터 처리 완료 => [0.3875732] 0
# 934번 인덱스 데이터 처리 완료 => [0.04930043] 0
# 935번 인덱스 데이터 처리 완료 => [0.87717986] 1
# 936번 인덱스 데이터 처리 완료 => [0.312975] 0
# 937번 인덱스 데이터 처리 완료 => [0.7072784] 1
# 938번 인덱스 데이터 처리 완료 => [0.29513234] 0
# 939번 인덱스 데이터 처리 완료 => [0.07033309] 0
# 940번 인덱스 데이터 처리 완료 => [0.6719152] 1
# 941번 인덱스 데이터 처리 완료 => [0.1805343] 0
# 942번 인덱스 데이터 처리 완료 => [0.6772721] 1
# 943번 인덱스 데이터 처리 완료 => [0.74683064] 1
# 944번 인덱스 데이터 처리 완료 => [0.61828274] 1
# 945번 인덱스 데이터 처리 완료 => [0.23555872] 0
# 946번 인덱스 데이터 처리 완료 => [0.2752813] 0
# 947번 인덱스 데이터 처리 완료 => [0.308685] 0
# 948번 인덱스 데이터 처리 완료 => [0.61838704] 1
# 949번 인덱스 데이터 처리 완료 => [0.01568395] 0
# 950번 인덱스 데이터 처리 완료 => [0.9811096] 1
# 951번 인덱스 데이터 처리 완료 => [0.17972584] 0
# 952번 인덱스 데이터 처리 완료 => [0.98635197] 1
# 953번 인덱스 데이터 처리 완료 => [0.6954365] 1
# 954번 인덱스 데이터 처리 완료 => [0.21597663] 0
# 955번 인덱스 데이터 처리 완료 => [0.8807019] 1
# 956번 인덱스 데이터 처리 완료 => [0.39454103] 0
# 957번 인덱스 데이터 처리 완료 => [0.36903557] 0
# 958번 인덱스 데이터 처리 완료 => [0.6233424] 1
# 959번 인덱스 데이터 처리 완료 => [0.01129622] 0
# 960번 인덱스 데이터 처리 완료 => [0.0087712] 0
# 961번 인덱스 데이터 처리 완료 => [0.9839392] 1
# 962번 인덱스 데이터 처리 완료 => [0.72415197] 1
# 963번 인덱스 데이터 처리 완료 => [0.8669322] 1
# 964번 인덱스 데이터 처리 완료 => [0.143491] 0
# 965번 인덱스 데이터 처리 완료 => [0.13050006] 0
# 966번 인덱스 데이터 처리 완료 => [0.7088704] 1
# 967번 인덱스 데이터 처리 완료 => [0.53914905] 1
# 968번 인덱스 데이터 처리 완료 => [0.97703904] 1
# 969번 인덱스 데이터 처리 완료 => [0.50226265] 1
# 970번 인덱스 데이터 처리 완료 => [0.95558447] 1
# 971번 인덱스 데이터 처리 완료 => [0.9956169] 1
# 972번 인덱스 데이터 처리 완료 => [0.4086979] 0
# 973번 인덱스 데이터 처리 완료 => [0.0202357] 0
# 974번 인덱스 데이터 처리 완료 => [0.08967472] 0
# 975번 인덱스 데이터 처리 완료 => [0.9229362] 1
# 976번 인덱스 데이터 처리 완료 => [0.01484982] 0
# 977번 인덱스 데이터 처리 완료 => [0.9515553] 1
# 978번 인덱스 데이터 처리 완료 => [0.6452371] 1
# 979번 인덱스 데이터 처리 완료 => [0.6189719] 1
# 980번 인덱스 데이터 처리 완료 => [0.94176966] 1
# 981번 인덱스 데이터 처리 완료 => [0.9804615] 1
# 982번 인덱스 데이터 처리 완료 => [0.63978493] 1
# 983번 인덱스 데이터 처리 완료 => [0.3087948] 0
# 984번 인덱스 데이터 처리 완료 => [0.96221846] 1
# 985번 인덱스 데이터 처리 완료 => [0.30069035] 0
# 986번 인덱스 데이터 처리 완료 => [0.00952815] 0
# 987번 인덱스 데이터 처리 완료 => [0.30039367] 0
# 988번 인덱스 데이터 처리 완료 => [0.04430612] 0
# 989번 인덱스 데이터 처리 완료 => [0.9626902] 1
# 990번 인덱스 데이터 처리 완료 => [0.3670268] 0
# 991번 인덱스 데이터 처리 완료 => [0.61179966] 1
# 992번 인덱스 데이터 처리 완료 => [0.04636902] 0
# 993번 인덱스 데이터 처리 완료 => [0.7174618] 1
# 994번 인덱스 데이터 처리 완료 => [0.74940383] 1
# 995번 인덱스 데이터 처리 완료 => [0.99024725] 1
# 996번 인덱스 데이터 처리 완료 => [0.06421325] 0
# 997번 인덱스 데이터 처리 완료 => [0.95139664] 1
# 998번 인덱스 데이터 처리 완료 => [0.03168628] 0
# 999번 인덱스 데이터 처리 완료 => [0.5409107] 1
# 1000번 인덱스 데이터 처리 완료 => [0.37219036] 0
# 1001번 인덱스 데이터 처리 완료 => [0.49823618] 0
# 1002번 인덱스 데이터 처리 완료 => [0.88172686] 1
# 1003번 인덱스 데이터 처리 완료 => [0.873755] 1
# 1004번 인덱스 데이터 처리 완료 => [0.16414158] 0
# 1005번 인덱스 데이터 처리 완료 => [0.19142014] 0
# 1006번 인덱스 데이터 처리 완료 => [0.00257054] 0
# 1007번 인덱스 데이터 처리 완료 => [0.96523565] 1
# 1008번 인덱스 데이터 처리 완료 => [0.9850558] 1
# 1009번 인덱스 데이터 처리 완료 => [0.9749287] 1
# 1010번 인덱스 데이터 처리 완료 => [0.9570848] 1
# 1011번 인덱스 데이터 처리 완료 => [0.30589426] 0
# 1012번 인덱스 데이터 처리 완료 => [0.19069642] 0
# 1013번 인덱스 데이터 처리 완료 => [0.58125764] 1
# 1014번 인덱스 데이터 처리 완료 => [0.06919728] 0
# 1015번 인덱스 데이터 처리 완료 => [0.93827736] 1
# 1016번 인덱스 데이터 처리 완료 => [0.09329457] 0
# 1017번 인덱스 데이터 처리 완료 => [0.25284886] 0
# 1018번 인덱스 데이터 처리 완료 => [0.47794926] 0
# 1019번 인덱스 데이터 처리 완료 => [0.07539736] 0
# 1020번 인덱스 데이터 처리 완료 => [0.38257593] 0
# 1021번 인덱스 데이터 처리 완료 => [0.9735238] 1
# 1022번 인덱스 데이터 처리 완료 => [0.97601354] 1
# 1023번 인덱스 데이터 처리 완료 => [0.98622173] 1
# 1024번 인덱스 데이터 처리 완료 => [0.42646438] 0
# 1025번 인덱스 데이터 처리 완료 => [0.0286935] 0
# 1026번 인덱스 데이터 처리 완료 => [0.7099967] 1
# 1027번 인덱스 데이터 처리 완료 => [0.9701321] 1
# 1028번 인덱스 데이터 처리 완료 => [0.78473437] 1
# 1029번 인덱스 데이터 처리 완료 => [0.08613876] 0
# 1030번 인덱스 데이터 처리 완료 => [0.10631165] 0
# 1031번 인덱스 데이터 처리 완료 => [0.79044557] 1
# 1032번 인덱스 데이터 처리 완료 => [0.35585746] 0
# 1033번 인덱스 데이터 처리 완료 => [0.6226807] 1
# 1034번 인덱스 데이터 처리 완료 => [0.5559805] 1
# 1035번 인덱스 데이터 처리 완료 => [0.94336677] 1
# 1036번 인덱스 데이터 처리 완료 => [0.14640743] 0
# 1037번 인덱스 데이터 처리 완료 => [0.47332096] 0
# 1038번 인덱스 데이터 처리 완료 => [0.8334251] 1
# 1039번 인덱스 데이터 처리 완료 => [0.69498676] 1
# 1040번 인덱스 데이터 처리 완료 => [0.47646672] 0
# 1041번 인덱스 데이터 처리 완료 => [0.01655757] 0
# 1042번 인덱스 데이터 처리 완료 => [0.01655757] 0
# 1043번 인덱스 데이터 처리 완료 => [0.05916368] 0
# 1044번 인덱스 데이터 처리 완료 => [0.05320355] 0
# 1045번 인덱스 데이터 처리 완료 => [0.40080604] 0
# 1046번 인덱스 데이터 처리 완료 => [0.93335235] 1
# 1047번 인덱스 데이터 처리 완료 => [0.22931127] 0
# 1048번 인덱스 데이터 처리 완료 => [0.98865426] 1
# 1049번 인덱스 데이터 처리 완료 => [0.32847407] 0
# 1050번 인덱스 데이터 처리 완료 => [0.9741029] 1
# 1051번 인덱스 데이터 처리 완료 => [0.02230105] 0
# 1052번 인덱스 데이터 처리 완료 => [0.96801746] 1
# 1053번 인덱스 데이터 처리 완료 => [0.2048044] 0
# 1054번 인덱스 데이터 처리 완료 => [0.9666322] 1
# 1055번 인덱스 데이터 처리 완료 => [0.9711835] 1
# 1056번 인덱스 데이터 처리 완료 => [0.10863312] 0
# 1057번 인덱스 데이터 처리 완료 => [0.022462] 0
# 1058번 인덱스 데이터 처리 완료 => [0.954083] 1
# 1059번 인덱스 데이터 처리 완료 => [0.32579327] 0
# 1060번 인덱스 데이터 처리 완료 => [0.02464032] 0
# 1061번 인덱스 데이터 처리 완료 => [0.35980347] 0
# 1062번 인덱스 데이터 처리 완료 => [0.09259861] 0
# 1063번 인덱스 데이터 처리 완료 => [0.9039189] 1
# 1064번 인덱스 데이터 처리 완료 => [0.03045994] 0
# 1065번 인덱스 데이터 처리 완료 => [0.9992847] 1
# 1066번 인덱스 데이터 처리 완료 => [0.39033815] 0
# 1067번 인덱스 데이터 처리 완료 => [0.18991008] 0
# 1068번 인덱스 데이터 처리 완료 => [0.06604041] 0
# 1069번 인덱스 데이터 처리 완료 => [0.957034] 1
# 1070번 인덱스 데이터 처리 완료 => [0.0524703] 0
# 1071번 인덱스 데이터 처리 완료 => [0.3592947] 0
# 1072번 인덱스 데이터 처리 완료 => [0.02129986] 0
# 1073번 인덱스 데이터 처리 완료 => [0.75264466] 1
# 1074번 인덱스 데이터 처리 완료 => [0.02265229] 0
# 1075번 인덱스 데이터 처리 완료 => [0.88309735] 1
# 1076번 인덱스 데이터 처리 완료 => [0.8827895] 1
# 1077번 인덱스 데이터 처리 완료 => [0.23423162] 0
# 1078번 인덱스 데이터 처리 완료 => [0.73436147] 1
# 1079번 인덱스 데이터 처리 완료 => [0.52174413] 1
# 1080번 인덱스 데이터 처리 완료 => [0.9967348] 1
# 1081번 인덱스 데이터 처리 완료 => [0.05548891] 0
# 1082번 인덱스 데이터 처리 완료 => [0.2362765] 0
# 1083번 인덱스 데이터 처리 완료 => [0.02965985] 0
# 1084번 인덱스 데이터 처리 완료 => [0.9716733] 1
# 1085번 인덱스 데이터 처리 완료 => [0.5004661] 1
# 1086번 인덱스 데이터 처리 완료 => [0.823932] 1
# 1087번 인덱스 데이터 처리 완료 => [0.9914671] 1
# 1088번 인덱스 데이터 처리 완료 => [0.01342488] 0
# 1089번 인덱스 데이터 처리 완료 => [0.14922349] 0
# 1090번 인덱스 데이터 처리 완료 => [0.01686869] 0
# 1091번 인덱스 데이터 처리 완료 => [0.9549991] 1
# 1092번 인덱스 데이터 처리 완료 => [0.9428955] 1
# 1093번 인덱스 데이터 처리 완료 => [0.42229703] 0
# 1094번 인덱스 데이터 처리 완료 => [0.68987846] 1
# 1095번 인덱스 데이터 처리 완료 => [0.03203123] 0
# 1096번 인덱스 데이터 처리 완료 => [0.0124269] 0
# 1097번 인덱스 데이터 처리 완료 => [0.4398927] 0
# 1098번 인덱스 데이터 처리 완료 => [0.8319693] 1
# 1099번 인덱스 데이터 처리 완료 => [0.94146043] 1
# 1100번 인덱스 데이터 처리 완료 => [0.0200534] 0
# 1101번 인덱스 데이터 처리 완료 => [0.0780192] 0
# 1102번 인덱스 데이터 처리 완료 => [0.32276493] 0
# 1103번 인덱스 데이터 처리 완료 => [0.14265127] 0
# 1104번 인덱스 데이터 처리 완료 => [0.4572869] 0
# 1105번 인덱스 데이터 처리 완료 => [0.22954984] 0
# 1106번 인덱스 데이터 처리 완료 => [0.09239212] 0
# 1107번 인덱스 데이터 처리 완료 => [0.7898418] 1
# 1108번 인덱스 데이터 처리 완료 => [0.50434947] 1
# 1109번 인덱스 데이터 처리 완료 => [0.07673178] 0
# 1110번 인덱스 데이터 처리 완료 => [0.06496929] 0
# 1111번 인덱스 데이터 처리 완료 => [0.99972636] 1
# 1112번 인덱스 데이터 처리 완료 => [0.2437826] 0
# 1113번 인덱스 데이터 처리 완료 => [0.42226523] 0
# 1114번 인덱스 데이터 처리 완료 => [0.3682379] 0
# 1115번 인덱스 데이터 처리 완료 => [0.47828642] 0
# 1116번 인덱스 데이터 처리 완료 => [0.37964594] 0
# 1117번 인덱스 데이터 처리 완료 => [0.99288917] 1
# 1118번 인덱스 데이터 처리 완료 => [0.25104365] 0
# 1119번 인덱스 데이터 처리 완료 => [0.02715002] 0
# 1120번 인덱스 데이터 처리 완료 => [0.09295508] 0
# 1121번 인덱스 데이터 처리 완료 => [0.57167757] 1
# 1122번 인덱스 데이터 처리 완료 => [0.09718475] 0
# 1123번 인덱스 데이터 처리 완료 => [0.06850905] 0
# 1124번 인덱스 데이터 처리 완료 => [0.96771014] 1
# 1125번 인덱스 데이터 처리 완료 => [0.01025146] 0
# 1126번 인덱스 데이터 처리 완료 => [0.39495385] 0
# 1127번 인덱스 데이터 처리 완료 => [0.33060458] 0
# 1128번 인덱스 데이터 처리 완료 => [0.04739403] 0
# 1129번 인덱스 데이터 처리 완료 => [0.86837757] 1
# 1130번 인덱스 데이터 처리 완료 => [0.3805771] 0
# 1131번 인덱스 데이터 처리 완료 => [0.9743741] 1
# 1132번 인덱스 데이터 처리 완료 => [0.9267435] 1
# 1133번 인덱스 데이터 처리 완료 => [0.942229] 1
# 1134번 인덱스 데이터 처리 완료 => [0.48455083] 0
# 1135번 인덱스 데이터 처리 완료 => [0.58422] 1
# 1136번 인덱스 데이터 처리 완료 => [0.8470449] 1
# 1137번 인덱스 데이터 처리 완료 => [0.42558837] 0
# 1138번 인덱스 데이터 처리 완료 => [0.04736666] 0
# 1139번 인덱스 데이터 처리 완료 => [0.02899489] 0
# 1140번 인덱스 데이터 처리 완료 => [0.19976972] 0
# 1141번 인덱스 데이터 처리 완료 => [0.10539781] 0
# 1142번 인덱스 데이터 처리 완료 => [0.90334684] 1
# 1143번 인덱스 데이터 처리 완료 => [0.90137815] 1
# 1144번 인덱스 데이터 처리 완료 => [0.44047228] 0
# 1145번 인덱스 데이터 처리 완료 => [0.9712295] 1
# 1146번 인덱스 데이터 처리 완료 => [0.8169365] 1
# 1147번 인덱스 데이터 처리 완료 => [0.96925396] 1
# 1148번 인덱스 데이터 처리 완료 => [0.08617616] 0
# 1149번 인덱스 데이터 처리 완료 => [0.23237729] 0
# 1150번 인덱스 데이터 처리 완료 => [0.3453984] 0
# 1151번 인덱스 데이터 처리 완료 => [0.75455266] 1
# 1152번 인덱스 데이터 처리 완료 => [0.35316804] 0
# 1153번 인덱스 데이터 처리 완료 => [0.05513667] 0
# 1154번 인덱스 데이터 처리 완료 => [0.25021818] 0
# 1155번 인덱스 데이터 처리 완료 => [0.95139664] 1
# 1156번 인덱스 데이터 처리 완료 => [0.6581787] 1
# 1157번 인덱스 데이터 처리 완료 => [0.5741629] 1
# 1158번 인덱스 데이터 처리 완료 => [0.36344248] 0
# 1159번 인덱스 데이터 처리 완료 => [0.02680327] 0
# 1160번 인덱스 데이터 처리 완료 => [0.10919526] 0
# 1161번 인덱스 데이터 처리 완료 => [0.24738641] 0
# 1162번 인덱스 데이터 처리 완료 => [0.95129144] 1
# 1163번 인덱스 데이터 처리 완료 => [0.2091555] 0
# 1164번 인덱스 데이터 처리 완료 => [0.53865093] 1
# 1165번 인덱스 데이터 처리 완료 => [0.34303388] 0
# 1166번 인덱스 데이터 처리 완료 => [0.03599233] 0
# 1167번 인덱스 데이터 처리 완료 => [0.3933375] 0
# 1168번 인덱스 데이터 처리 완료 => [0.69498676] 1
# 1169번 인덱스 데이터 처리 완료 => [0.9274505] 1
# 1170번 인덱스 데이터 처리 완료 => [0.87566227] 1
# 1171번 인덱스 데이터 처리 완료 => [0.9093072] 1
# 1172번 인덱스 데이터 처리 완료 => [0.0569721] 0
# 1173번 인덱스 데이터 처리 완료 => [0.00693617] 0
# 1174번 인덱스 데이터 처리 완료 => [0.35529727] 0
# 1175번 인덱스 데이터 처리 완료 => [0.57741296] 1
# 1176번 인덱스 데이터 처리 완료 => [0.19327411] 0
# 1177번 인덱스 데이터 처리 완료 => [0.19712704] 0
# 1178번 인덱스 데이터 처리 완료 => [0.7576454] 1
# 1179번 인덱스 데이터 처리 완료 => [0.86622036] 1
# 1180번 인덱스 데이터 처리 완료 => [0.47434878] 0
# 1181번 인덱스 데이터 처리 완료 => [0.88445216] 1
# 1182번 인덱스 데이터 처리 완료 => [0.603321] 1
# 1183번 인덱스 데이터 처리 완료 => [0.9265691] 1
# 1184번 인덱스 데이터 처리 완료 => [0.17601568] 0
# 1185번 인덱스 데이터 처리 완료 => [0.8896476] 1
# 1186번 인덱스 데이터 처리 완료 => [0.91646385] 1
# 1187번 인덱스 데이터 처리 완료 => [0.7049077] 1
# 1188번 인덱스 데이터 처리 완료 => [0.9582808] 1
# 1189번 인덱스 데이터 처리 완료 => [0.00223511] 0
# 1190번 인덱스 데이터 처리 완료 => [0.9403934] 1
# 1191번 인덱스 데이터 처리 완료 => [0.45575675] 0
# 1192번 인덱스 데이터 처리 완료 => [0.4712252] 0
# 1193번 인덱스 데이터 처리 완료 => [0.9484539] 1
# 1194번 인덱스 데이터 처리 완료 => [0.00021354] 0
# 1195번 인덱스 데이터 처리 완료 => [0.55390286] 1
# 1196번 인덱스 데이터 처리 완료 => [0.7334529] 1
# 1197번 인덱스 데이터 처리 완료 => [0.72097814] 1
# 1198번 인덱스 데이터 처리 완료 => [0.56786895] 1
# 1199번 인덱스 데이터 처리 완료 => [0.83220327] 1
# 1200번 인덱스 데이터 처리 완료 => [0.01350252] 0
# 1201번 인덱스 데이터 처리 완료 => [0.9115672] 1
# 1202번 인덱스 데이터 처리 완료 => [0.01478571] 0
# 1203번 인덱스 데이터 처리 완료 => [0.13784924] 0
# 1204번 인덱스 데이터 처리 완료 => [0.01890642] 0
# 1205번 인덱스 데이터 처리 완료 => [0.14272356] 0
# 1206번 인덱스 데이터 처리 완료 => [0.01757537] 0
# 1207번 인덱스 데이터 처리 완료 => [0.16615535] 0
# 1208번 인덱스 데이터 처리 완료 => [0.8442289] 1
# 1209번 인덱스 데이터 처리 완료 => [0.00140007] 0
# 1210번 인덱스 데이터 처리 완료 => [0.68215406] 1
# 1211번 인덱스 데이터 처리 완료 => [0.03411397] 0
# 1212번 인덱스 데이터 처리 완료 => [0.08467738] 0
# 1213번 인덱스 데이터 처리 완료 => [0.0032227] 0
# 1214번 인덱스 데이터 처리 완료 => [0.17033185] 0
# 1215번 인덱스 데이터 처리 완료 => [0.98620427] 1
# 1216번 인덱스 데이터 처리 완료 => [0.5564824] 1
# 1217번 인덱스 데이터 처리 완료 => [0.92555165] 1
# 1218번 인덱스 데이터 처리 완료 => [0.24404682] 0
# 1219번 인덱스 데이터 처리 완료 => [0.37538907] 0
# 1220번 인덱스 데이터 처리 완료 => [0.16390817] 0
# 1221번 인덱스 데이터 처리 완료 => [0.7837518] 1
# 1222번 인덱스 데이터 처리 완료 => [0.6364614] 1
# 1223번 인덱스 데이터 처리 완료 => [0.86207616] 1
# 1224번 인덱스 데이터 처리 완료 => [0.547959] 1
# 1225번 인덱스 데이터 처리 완료 => [0.8005998] 1
# 1226번 인덱스 데이터 처리 완료 => [0.35057342] 0
# 1227번 인덱스 데이터 처리 완료 => [0.9725257] 1
# 1228번 인덱스 데이터 처리 완료 => [0.91338736] 1
# 1229번 인덱스 데이터 처리 완료 => [0.37795347] 0
# 1230번 인덱스 데이터 처리 완료 => [0.18839028] 0
# 1231번 인덱스 데이터 처리 완료 => [0.4556124] 0
# 1232번 인덱스 데이터 처리 완료 => [0.01991181] 0
# 1233번 인덱스 데이터 처리 완료 => [0.5342928] 1
# 1234번 인덱스 데이터 처리 완료 => [0.93439615] 1
# 1235번 인덱스 데이터 처리 완료 => [0.78727037] 1
# 1236번 인덱스 데이터 처리 완료 => [0.46430472] 0
# 1237번 인덱스 데이터 처리 완료 => [0.07325722] 0
# 1238번 인덱스 데이터 처리 완료 => [0.3213463] 0
# 1239번 인덱스 데이터 처리 완료 => [0.2021082] 0
# 1240번 인덱스 데이터 처리 완료 => [0.0027972] 0
# 1241번 인덱스 데이터 처리 완료 => [0.06810038] 0
# 1242번 인덱스 데이터 처리 완료 => [0.3390127] 0
# 1243번 인덱스 데이터 처리 완료 => [0.59936637] 1
# 1244번 인덱스 데이터 처리 완료 => [0.04154504] 0
# 1245번 인덱스 데이터 처리 완료 => [0.21320273] 0
# 1246번 인덱스 데이터 처리 완료 => [0.98806924] 1
# 1247번 인덱스 데이터 처리 완료 => [0.581921] 1
# 1248번 인덱스 데이터 처리 완료 => [0.00142183] 0
# 1249번 인덱스 데이터 처리 완료 => [0.83974457] 1
# 1250번 인덱스 데이터 처리 완료 => [0.44146636] 0
# 1251번 인덱스 데이터 처리 완료 => [0.49241942] 0
# 1252번 인덱스 데이터 처리 완료 => [0.4881846] 0
# 1253번 인덱스 데이터 처리 완료 => [0.13436662] 0
# 1254번 인덱스 데이터 처리 완료 => [0.8655115] 1
# 1255번 인덱스 데이터 처리 완료 => [0.06428505] 0
# 1256번 인덱스 데이터 처리 완료 => [0.547959] 1
# 1257번 인덱스 데이터 처리 완료 => [0.8486082] 1
# 1258번 인덱스 데이터 처리 완료 => [0.03959204] 0
# 1259번 인덱스 데이터 처리 완료 => [0.72798365] 1
# 1260번 인덱스 데이터 처리 완료 => [0.547959] 1
# 1261번 인덱스 데이터 처리 완료 => [0.6163494] 1
# 1262번 인덱스 데이터 처리 완료 => [0.82363516] 1
# 1263번 인덱스 데이터 처리 완료 => [0.39294356] 0
# 1264번 인덱스 데이터 처리 완료 => [0.04746363] 0
# 1265번 인덱스 데이터 처리 완료 => [0.9958884] 1
# 1266번 인덱스 데이터 처리 완료 => [0.7441014] 1
# 1267번 인덱스 데이터 처리 완료 => [0.64395034] 1
# 1268번 인덱스 데이터 처리 완료 => [0.15688893] 0
# 1269번 인덱스 데이터 처리 완료 => [0.8483724] 1
# 1270번 인덱스 데이터 처리 완료 => [0.05027297] 0
# 1271번 인덱스 데이터 처리 완료 => [0.45228004] 0
# 1272번 인덱스 데이터 처리 완료 => [0.95547336] 1
# 1273번 인덱스 데이터 처리 완료 => [0.02806116] 0
# 1274번 인덱스 데이터 처리 완료 => [0.547959] 1
# 1275번 인덱스 데이터 처리 완료 => [0.17996804] 0
# 1276번 인덱스 데이터 처리 완료 => [0.28293592] 0
# 1277번 인덱스 데이터 처리 완료 => [0.9534429] 1
# 1278번 인덱스 데이터 처리 완료 => [0.0574781] 0
# 1279번 인덱스 데이터 처리 완료 => [0.7925182] 1
# 1280번 인덱스 데이터 처리 완료 => [0.8968836] 1
# 1281번 인덱스 데이터 처리 완료 => [0.03215095] 0
# 1282번 인덱스 데이터 처리 완료 => [0.00362989] 0
# 1283번 인덱스 데이터 처리 완료 => [0.547959] 1
# 1284번 인덱스 데이터 처리 완료 => [0.06807578] 0
# 1285번 인덱스 데이터 처리 완료 => [0.86652976] 1
# 1286번 인덱스 데이터 처리 완료 => [0.48538545] 0
# 1287번 인덱스 데이터 처리 완료 => [0.9732265] 1
# 1288번 인덱스 데이터 처리 완료 => [0.09780163] 0
# 1289번 인덱스 데이터 처리 완료 => [0.547959] 1
# 1290번 인덱스 데이터 처리 완료 => [0.00949063] 0
# 1291번 인덱스 데이터 처리 완료 => [0.39874655] 0
# 1292번 인덱스 데이터 처리 완료 => [0.6755895] 1
# 1293번 인덱스 데이터 처리 완료 => [0.98110205] 1
# 1294번 인덱스 데이터 처리 완료 => [0.15528794] 0
# 1295번 인덱스 데이터 처리 완료 => [0.24630846] 0
# 1296번 인덱스 데이터 처리 완료 => [0.00818955] 0
# 1297번 인덱스 데이터 처리 완료 => [0.9983551] 1
# 1298번 인덱스 데이터 처리 완료 => [0.0601285] 0
# 1299번 인덱스 데이터 처리 완료 => [0.878116] 1
# 1300번 인덱스 데이터 처리 완료 => [0.8738718] 1
# 1301번 인덱스 데이터 처리 완료 => [0.02000676] 0
# 1302번 인덱스 데이터 처리 완료 => [0.70354277] 1
# 1303번 인덱스 데이터 처리 완료 => [0.20583391] 0
# 1304번 인덱스 데이터 처리 완료 => [0.4719665] 0
# 1305번 인덱스 데이터 처리 완료 => [0.9747345] 1
# 1306번 인덱스 데이터 처리 완료 => [0.37817] 0
# 1307번 인덱스 데이터 처리 완료 => [0.36224234] 0
# ...
# 10773번 인덱스 데이터 처리 완료 => [0.9089594] 1
# 10774번 인덱스 데이터 처리 완료 => [0.58157223] 1
# 10775번 인덱스 데이터 처리 완료 => [0.821154] 1
# 10776번 인덱스 데이터 처리 완료 => [0.49564627] 0
# 10777번 인덱스 데이터 처리 완료 => [0.9894699] 1
# 10778번 인덱스 데이터 처리 완료 => [0.99003357] 1
# 10779번 인덱스 데이터 처리 완료 => [0.9953499] 1
# 10780번 인덱스 데이터 처리 완료 => [0.22853263] 0
# 10781번 인덱스 데이터 처리 완료 => [0.6404182] 1
# 10782번 인덱스 데이터 처리 완료 => [0.13463286] 0
# 10783번 인덱스 데이터 처리 완료 => [0.9083694] 1
# 10784번 인덱스 데이터 처리 완료 => [0.35474345] 0
# 10785번 인덱스 데이터 처리 완료 => [0.21615402] 0
# 10786번 인덱스 데이터 처리 완료 => [0.92974216] 1
# 10787번 인덱스 데이터 처리 완료 => [0.2569514] 0
# 10788번 인덱스 데이터 처리 완료 => [0.39680094] 0
# 10789번 인덱스 데이터 처리 완료 => [0.50810164] 1
# 10790번 인덱스 데이터 처리 완료 => [0.52312857] 1
# 10791번 인덱스 데이터 처리 완료 => [0.19897673] 0
# 10792번 인덱스 데이터 처리 완료 => [0.64913106] 1
# 10793번 인덱스 데이터 처리 완료 => [0.93427336] 1
# 10794번 인덱스 데이터 처리 완료 => [0.27331284] 0
# 10795번 인덱스 데이터 처리 완료 => [0.7877714] 1
# 10796번 인덱스 데이터 처리 완료 => [0.4147816] 0
# 10797번 인덱스 데이터 처리 완료 => [0.99044484] 1
# 10798번 인덱스 데이터 처리 완료 => [0.95993817] 1
# 10799번 인덱스 데이터 처리 완료 => [0.04267046] 0
# 10800번 인덱스 데이터 처리 완료 => [0.09136829] 0
# 10801번 인덱스 데이터 처리 완료 => [0.74884295] 1
# 10802번 인덱스 데이터 처리 완료 => [0.98749566] 1
# 10803번 인덱스 데이터 처리 완료 => [0.03802302] 0
# 10804번 인덱스 데이터 처리 완료 => [0.00805653] 0
# 10805번 인덱스 데이터 처리 완료 => [0.4755217] 0
# 10806번 인덱스 데이터 처리 완료 => [0.8753271] 1
# 10807번 인덱스 데이터 처리 완료 => [0.01177873] 0
# 10808번 인덱스 데이터 처리 완료 => [0.18462579] 0
# 10809번 인덱스 데이터 처리 완료 => [0.733738] 1
# 10810번 인덱스 데이터 처리 완료 => [0.8978578] 1
# 10811번 인덱스 데이터 처리 완료 => [0.04044643] 0
# 10812번 인덱스 데이터 처리 완료 => [0.4064026] 0
# 10813번 인덱스 데이터 처리 완료 => [0.47742426] 0
# 10814번 인덱스 데이터 처리 완료 => [0.47857368] 0
# 10815번 인덱스 데이터 처리 완료 => [0.55708253] 1
# 10816번 인덱스 데이터 처리 완료 => [0.9427204] 1
# 10817번 인덱스 데이터 처리 완료 => [0.16279514] 0
# 10818번 인덱스 데이터 처리 완료 => [0.7745728] 1
# 10819번 인덱스 데이터 처리 완료 => [0.9558203] 1
# 10820번 인덱스 데이터 처리 완료 => [0.23603414] 0
# 10821번 인덱스 데이터 처리 완료 => [0.9623821] 1
# 10822번 인덱스 데이터 처리 완료 => [0.50579154] 1
# 10823번 인덱스 데이터 처리 완료 => [0.87986] 1
# 10824번 인덱스 데이터 처리 완료 => [0.7623981] 1
# 10825번 인덱스 데이터 처리 완료 => [0.9752592] 1
# 10826번 인덱스 데이터 처리 완료 => [0.0339009] 0
# 10827번 인덱스 데이터 처리 완료 => [0.10087851] 0
# 10828번 인덱스 데이터 처리 완료 => [0.02104619] 0
# 10829번 인덱스 데이터 처리 완료 => [0.9984114] 1
# 10830번 인덱스 데이터 처리 완료 => [0.6004827] 1
# 10831번 인덱스 데이터 처리 완료 => [0.0513611] 0
# 10832번 인덱스 데이터 처리 완료 => [0.79031163] 1
# 10833번 인덱스 데이터 처리 완료 => [0.27754632] 0
# 10834번 인덱스 데이터 처리 완료 => [0.94946945] 1
# 10835번 인덱스 데이터 처리 완료 => [0.05166616] 0
# 10836번 인덱스 데이터 처리 완료 => [0.53808206] 1
# 10837번 인덱스 데이터 처리 완료 => [0.07911943] 0
# 10838번 인덱스 데이터 처리 완료 => [0.4229645] 0
# 10839번 인덱스 데이터 처리 완료 => [0.15837272] 0
# 10840번 인덱스 데이터 처리 완료 => [0.00030035] 0
# 10841번 인덱스 데이터 처리 완료 => [0.8670497] 1
# 10842번 인덱스 데이터 처리 완료 => [0.9063557] 1
# 10843번 인덱스 데이터 처리 완료 => [0.7317853] 1
# 10844번 인덱스 데이터 처리 완료 => [0.01651258] 0
# 10845번 인덱스 데이터 처리 완료 => [0.98375964] 1
# 10846번 인덱스 데이터 처리 완료 => [0.36449856] 0
# 10847번 인덱스 데이터 처리 완료 => [0.9879995] 1
# 10848번 인덱스 데이터 처리 완료 => [0.966817] 1
# 10849번 인덱스 데이터 처리 완료 => [0.75758684] 1
# 10850번 인덱스 데이터 처리 완료 => [0.60965806] 1
# 10851번 인덱스 데이터 처리 완료 => [0.07950626] 0
# 10852번 인덱스 데이터 처리 완료 => [0.01398249] 0
# 10853번 인덱스 데이터 처리 완료 => [0.0924642] 0
# 10854번 인덱스 데이터 처리 완료 => [0.3788962] 0
# 10855번 인덱스 데이터 처리 완료 => [0.92137724] 1
# 10856번 인덱스 데이터 처리 완료 => [0.73141325] 1
# 10857번 인덱스 데이터 처리 완료 => [0.31385553] 0
# 10858번 인덱스 데이터 처리 완료 => [0.06826735] 0
# 10859번 인덱스 데이터 처리 완료 => [0.90995574] 1
# 10860번 인덱스 데이터 처리 완료 => [0.99290586] 1
# 10861번 인덱스 데이터 처리 완료 => [0.9699173] 1
# 10862번 인덱스 데이터 처리 완료 => [0.97789884] 1
# 10863번 인덱스 데이터 처리 완료 => [0.05151266] 0
# 10864번 인덱스 데이터 처리 완료 => [0.32459885] 0
# 10865번 인덱스 데이터 처리 완료 => [0.9172858] 1
# 10866번 인덱스 데이터 처리 완료 => [0.02271233] 0
# 10867번 인덱스 데이터 처리 완료 => [0.97301745] 1
# 10868번 인덱스 데이터 처리 완료 => [0.320564] 0
# 10869번 인덱스 데이터 처리 완료 => [0.17778504] 0
# 10870번 인덱스 데이터 처리 완료 => [0.99857795] 1
# 10871번 인덱스 데이터 처리 완료 => [0.9234739] 1
# 10872번 인덱스 데이터 처리 완료 => [0.17257497] 0
# 10873번 인덱스 데이터 처리 완료 => [0.73897064] 1
# 10874번 인덱스 데이터 처리 완료 => [0.04864204] 0
# 10875번 인덱스 데이터 처리 완료 => [0.23833282] 0
# 10876번 인덱스 데이터 처리 완료 => [0.32790694] 0
# 10877번 인덱스 데이터 처리 완료 => [0.9191632] 1
# 10878번 인덱스 데이터 처리 완료 => [0.6988744] 1
# 10879번 인덱스 데이터 처리 완료 => [0.19311498] 0
# 10880번 인덱스 데이터 처리 완료 => [0.07455398] 0
# 10881번 인덱스 데이터 처리 완료 => [0.3029208] 0
# 10882번 인덱스 데이터 처리 완료 => [0.7406398] 1
# 10883번 인덱스 데이터 처리 완료 => [0.82429415] 1
# 10884번 인덱스 데이터 처리 완료 => [0.455017] 0
# 10885번 인덱스 데이터 처리 완료 => [0.18870804] 0
# 10886번 인덱스 데이터 처리 완료 => [0.6844125] 1
# 10887번 인덱스 데이터 처리 완료 => [0.9379036] 1
# 10888번 인덱스 데이터 처리 완료 => [0.9959865] 1
# 10889번 인덱스 데이터 처리 완료 => [0.957733] 1
# 10890번 인덱스 데이터 처리 완료 => [0.74975026] 1
# 10891번 인덱스 데이터 처리 완료 => [0.71925277] 1
# 10892번 인덱스 데이터 처리 완료 => [0.99881184] 1
# 10893번 인덱스 데이터 처리 완료 => [0.07596237] 0
# 10894번 인덱스 데이터 처리 완료 => [0.18794085] 0
# 10895번 인덱스 데이터 처리 완료 => [0.81299585] 1
# 10896번 인덱스 데이터 처리 완료 => [0.05139726] 0
# 10897번 인덱스 데이터 처리 완료 => [0.12239968] 0
# 10898번 인덱스 데이터 처리 완료 => [0.03118817] 0
# 10899번 인덱스 데이터 처리 완료 => [0.9187402] 1
# 10900번 인덱스 데이터 처리 완료 => [0.33552477] 0
# 10901번 인덱스 데이터 처리 완료 => [0.0854412] 0
# 10902번 인덱스 데이터 처리 완료 => [0.17158808] 0
# 10903번 인덱스 데이터 처리 완료 => [0.99331564] 1
# 10904번 인덱스 데이터 처리 완료 => [0.99007857] 1
# 10905번 인덱스 데이터 처리 완료 => [0.96824974] 1
# 10906번 인덱스 데이터 처리 완료 => [0.7033836] 1
# 10907번 인덱스 데이터 처리 완료 => [0.05391775] 0
# 10908번 인덱스 데이터 처리 완료 => [0.4405463] 0
# 10909번 인덱스 데이터 처리 완료 => [0.9925291] 1
# 10910번 인덱스 데이터 처리 완료 => [0.56441903] 1
# 10911번 인덱스 데이터 처리 완료 => [0.425855] 0
# 10912번 인덱스 데이터 처리 완료 => [0.8970318] 1
# 10913번 인덱스 데이터 처리 완료 => [0.57472223] 1
# 10914번 인덱스 데이터 처리 완료 => [0.36029595] 0
# 10915번 인덱스 데이터 처리 완료 => [0.1673249] 0
# 10916번 인덱스 데이터 처리 완료 => [0.0339266] 0
# 10917번 인덱스 데이터 처리 완료 => [0.3939541] 0
# 10918번 인덱스 데이터 처리 완료 => [0.42600468] 0
# 10919번 인덱스 데이터 처리 완료 => [0.4937128] 0
# 10920번 인덱스 데이터 처리 완료 => [0.7014637] 1
# 10921번 인덱스 데이터 처리 완료 => [0.40994823] 0
# 10922번 인덱스 데이터 처리 완료 => [0.02016555] 0
# 10923번 인덱스 데이터 처리 완료 => [0.08666207] 0
# 10924번 인덱스 데이터 처리 완료 => [0.84140384] 1
# 10925번 인덱스 데이터 처리 완료 => [0.547959] 1
# 10926번 인덱스 데이터 처리 완료 => [0.4041548] 0
# 10927번 인덱스 데이터 처리 완료 => [0.7272618] 1
# 10928번 인덱스 데이터 처리 완료 => [0.5737648] 1
# 10929번 인덱스 데이터 처리 완료 => [0.9693569] 1
# 10930번 인덱스 데이터 처리 완료 => [0.9876864] 1
# 10931번 인덱스 데이터 처리 완료 => [0.00845466] 0
# 10932번 인덱스 데이터 처리 완료 => [0.9148771] 1
# 10933번 인덱스 데이터 처리 완료 => [0.00149297] 0
# 10934번 인덱스 데이터 처리 완료 => [0.41426173] 0
# 10935번 인덱스 데이터 처리 완료 => [0.91338754] 1
# 10936번 인덱스 데이터 처리 완료 => [0.14991422] 0
# 10937번 인덱스 데이터 처리 완료 => [0.88513213] 1
# 10938번 인덱스 데이터 처리 완료 => [0.21492155] 0
# 10939번 인덱스 데이터 처리 완료 => [0.07472562] 0
# 10940번 인덱스 데이터 처리 완료 => [0.30842486] 0
# 10941번 인덱스 데이터 처리 완료 => [0.06162846] 0
# 10942번 인덱스 데이터 처리 완료 => [0.95383066] 1
# 10943번 인덱스 데이터 처리 완료 => [0.03521851] 0
# 10944번 인덱스 데이터 처리 완료 => [0.69023275] 1
# 10945번 인덱스 데이터 처리 완료 => [0.08126323] 0
# 10946번 인덱스 데이터 처리 완료 => [0.7904602] 1
# 10947번 인덱스 데이터 처리 완료 => [0.6822567] 1
# 10948번 인덱스 데이터 처리 완료 => [0.44972554] 0
# 10949번 인덱스 데이터 처리 완료 => [0.9932288] 1
# 10950번 인덱스 데이터 처리 완료 => [0.09516538] 0
# 10951번 인덱스 데이터 처리 완료 => [0.75020254] 1
# 10952번 인덱스 데이터 처리 완료 => [0.7987368] 1
# 10953번 인덱스 데이터 처리 완료 => [0.3892983] 0
# 10954번 인덱스 데이터 처리 완료 => [0.93459386] 1
# 10955번 인덱스 데이터 처리 완료 => [0.891507] 1
# 10956번 인덱스 데이터 처리 완료 => [0.22147134] 0
# 10957번 인덱스 데이터 처리 완료 => [0.22569196] 0
# 10958번 인덱스 데이터 처리 완료 => [0.60704625] 1
# 10959번 인덱스 데이터 처리 완료 => [0.03612058] 0
# 10960번 인덱스 데이터 처리 완료 => [0.57068217] 1
# 10961번 인덱스 데이터 처리 완료 => [0.5144057] 1
# 10962번 인덱스 데이터 처리 완료 => [0.8295152] 1
# 10963번 인덱스 데이터 처리 완료 => [0.36019626] 0
# 10964번 인덱스 데이터 처리 완료 => [0.53982496] 1
# 10965번 인덱스 데이터 처리 완료 => [0.9022892] 1
# 10966번 인덱스 데이터 처리 완료 => [0.7702479] 1
# 10967번 인덱스 데이터 처리 완료 => [0.84445274] 1
# 10968번 인덱스 데이터 처리 완료 => [0.96215045] 1
# 10969번 인덱스 데이터 처리 완료 => [0.97129714] 1
# 10970번 인덱스 데이터 처리 완료 => [0.08010853] 0
# 10971번 인덱스 데이터 처리 완료 => [0.96470726] 1
# 10972번 인덱스 데이터 처리 완료 => [0.7962139] 1
# 10973번 인덱스 데이터 처리 완료 => [0.6826351] 1
# 10974번 인덱스 데이터 처리 완료 => [0.7724926] 1
# 10975번 인덱스 데이터 처리 완료 => [0.8782473] 1
# 10976번 인덱스 데이터 처리 완료 => [0.82061076] 1
# 10977번 인덱스 데이터 처리 완료 => [0.62495685] 1
# 10978번 인덱스 데이터 처리 완료 => [0.96354073] 1
# 10979번 인덱스 데이터 처리 완료 => [0.33891436] 0
# 10980번 인덱스 데이터 처리 완료 => [0.1482505] 0
# 10981번 인덱스 데이터 처리 완료 => [0.99769706] 1
# 10982번 인덱스 데이터 처리 완료 => [0.6890266] 1
# 10983번 인덱스 데이터 처리 완료 => [0.7321486] 1
# 10984번 인덱스 데이터 처리 완료 => [0.6758673] 1
# 10985번 인덱스 데이터 처리 완료 => [0.78636366] 1
# 10986번 인덱스 데이터 처리 완료 => [0.6264424] 1
# 10987번 인덱스 데이터 처리 완료 => [0.4558806] 0
# 10988번 인덱스 데이터 처리 완료 => [0.7572356] 1
# 10989번 인덱스 데이터 처리 완료 => [0.97669923] 1
# 10990번 인덱스 데이터 처리 완료 => [0.34537616] 0
# 10991번 인덱스 데이터 처리 완료 => [0.80057216] 1
# 10992번 인덱스 데이터 처리 완료 => [0.03005203] 0
# 10993번 인덱스 데이터 처리 완료 => [0.44893697] 0
# 10994번 인덱스 데이터 처리 완료 => [0.76850957] 1
# 10995번 인덱스 데이터 처리 완료 => [0.13609625] 0
# 10996번 인덱스 데이터 처리 완료 => [0.3230072] 0
# 10997번 인덱스 데이터 처리 완료 => [0.46120557] 0
# 10998번 인덱스 데이터 처리 완료 => [0.31954572] 0
# 10999번 인덱스 데이터 처리 완료 => [0.76993525] 1
# 11000번 인덱스 데이터 처리 완료 => [0.14001864] 0
# 11001번 인덱스 데이터 처리 완료 => [0.9930675] 1
# 11002번 인덱스 데이터 처리 완료 => [0.3350351] 0
# 11003번 인덱스 데이터 처리 완료 => [0.27523008] 0
# 11004번 인덱스 데이터 처리 완료 => [0.37243253] 0
# 11005번 인덱스 데이터 처리 완료 => [0.9804551] 1
# 11006번 인덱스 데이터 처리 완료 => [0.19035903] 0
# 11007번 인덱스 데이터 처리 완료 => [0.36809897] 0
# 11008번 인덱스 데이터 처리 완료 => [0.93726146] 1
# 11009번 인덱스 데이터 처리 완료 => [0.98590106] 1
# 11010번 인덱스 데이터 처리 완료 => [0.964937] 1
# 11011번 인덱스 데이터 처리 완료 => [0.981041] 1
# 11012번 인덱스 데이터 처리 완료 => [0.10013737] 0
# 11013번 인덱스 데이터 처리 완료 => [0.9833278] 1
# 11014번 인덱스 데이터 처리 완료 => [0.40576953] 0
# 11015번 인덱스 데이터 처리 완료 => [0.89083457] 1
# 11016번 인덱스 데이터 처리 완료 => [0.9982924] 1
# 11017번 인덱스 데이터 처리 완료 => [0.20202021] 0
# 11018번 인덱스 데이터 처리 완료 => [0.99482405] 1
# 11019번 인덱스 데이터 처리 완료 => [0.8815182] 1
# 11020번 인덱스 데이터 처리 완료 => [0.6352406] 1
# 11021번 인덱스 데이터 처리 완료 => [0.03363803] 0
# 11022번 인덱스 데이터 처리 완료 => [0.14477243] 0
# 11023번 인덱스 데이터 처리 완료 => [0.01475788] 0
# 11024번 인덱스 데이터 처리 완료 => [0.64952594] 1
# 11025번 인덱스 데이터 처리 완료 => [0.9610275] 1
# 11026번 인덱스 데이터 처리 완료 => [0.83693653] 1
# 11027번 인덱스 데이터 처리 완료 => [0.9889753] 1
# 11028번 인덱스 데이터 처리 완료 => [0.7588047] 1
# 11029번 인덱스 데이터 처리 완료 => [0.0170536] 0
# 11030번 인덱스 데이터 처리 완료 => [0.9976036] 1
# 11031번 인덱스 데이터 처리 완료 => [0.95281726] 1
# 11032번 인덱스 데이터 처리 완료 => [0.98106235] 1
# 11033번 인덱스 데이터 처리 완료 => [0.02140394] 0
# 11034번 인덱스 데이터 처리 완료 => [0.33539578] 0
# 11035번 인덱스 데이터 처리 완료 => [0.43187922] 0
# 11036번 인덱스 데이터 처리 완료 => [0.8616584] 1
# 11037번 인덱스 데이터 처리 완료 => [0.16893709] 0
# 11038번 인덱스 데이터 처리 완료 => [0.9949995] 1
# 11039번 인덱스 데이터 처리 완료 => [0.49398744] 0
# 11040번 인덱스 데이터 처리 완료 => [0.9868133] 1
# 11041번 인덱스 데이터 처리 완료 => [0.2602925] 0
# 11042번 인덱스 데이터 처리 완료 => [0.914289] 1
# 11043번 인덱스 데이터 처리 완료 => [0.7317824] 1
# 11044번 인덱스 데이터 처리 완료 => [0.8832471] 1
# 11045번 인덱스 데이터 처리 완료 => [0.9542442] 1
# 11046번 인덱스 데이터 처리 완료 => [0.052389] 0
# 11047번 인덱스 데이터 처리 완료 => [0.36958027] 0
# 11048번 인덱스 데이터 처리 완료 => [0.9905088] 1
# 11049번 인덱스 데이터 처리 완료 => [0.58515185] 1
# 11050번 인덱스 데이터 처리 완료 => [0.9798779] 1
# 11051번 인덱스 데이터 처리 완료 => [0.03488072] 0
# 11052번 인덱스 데이터 처리 완료 => [0.04211684] 0
# 11053번 인덱스 데이터 처리 완료 => [0.04354365] 0
# 11054번 인덱스 데이터 처리 완료 => [0.93052745] 1
# 11055번 인덱스 데이터 처리 완료 => [0.20666969] 0
# 11056번 인덱스 데이터 처리 완료 => [0.4075655] 0
# 11057번 인덱스 데이터 처리 완료 => [0.00722463] 0
# 11058번 인덱스 데이터 처리 완료 => [0.36199996] 0
# 11059번 인덱스 데이터 처리 완료 => [0.1749267] 0
# 11060번 인덱스 데이터 처리 완료 => [0.9937568] 1
# 11061번 인덱스 데이터 처리 완료 => [0.39777035] 0
# 11062번 인덱스 데이터 처리 완료 => [0.9923327] 1
# 11063번 인덱스 데이터 처리 완료 => [0.16315036] 0
# 11064번 인덱스 데이터 처리 완료 => [0.80038464] 1
# 11065번 인덱스 데이터 처리 완료 => [0.84838265] 1
# 11066번 인덱스 데이터 처리 완료 => [0.7425943] 1
# 11067번 인덱스 데이터 처리 완료 => [0.47581407] 0
# 11068번 인덱스 데이터 처리 완료 => [0.93332] 1
# 11069번 인덱스 데이터 처리 완료 => [0.6895246] 1
# 11070번 인덱스 데이터 처리 완료 => [0.3398655] 0
# 11071번 인덱스 데이터 처리 완료 => [0.27518848] 0
# 11072번 인덱스 데이터 처리 완료 => [0.09357913] 0
# 11073번 인덱스 데이터 처리 완료 => [0.15268369] 0
# 11074번 인덱스 데이터 처리 완료 => [0.86791] 1
# 11075번 인덱스 데이터 처리 완료 => [0.5158424] 1
# 11076번 인덱스 데이터 처리 완료 => [0.05034425] 0
# 11077번 인덱스 데이터 처리 완료 => [0.7568925] 1
# 11078번 인덱스 데이터 처리 완료 => [0.8863686] 1
# 11079번 인덱스 데이터 처리 완료 => [0.16715841] 0
# 11080번 인덱스 데이터 처리 완료 => [0.40274948] 0
# 11081번 인덱스 데이터 처리 완료 => [0.97404975] 1
# 11082번 인덱스 데이터 처리 완료 => [0.00140958] 0
# 11083번 인덱스 데이터 처리 완료 => [0.13496996] 0
# 11084번 인덱스 데이터 처리 완료 => [0.05005212] 0
# 11085번 인덱스 데이터 처리 완료 => [0.9483088] 1
# 11086번 인덱스 데이터 처리 완료 => [0.46971118] 0
# 11087번 인덱스 데이터 처리 완료 => [0.9013818] 1
# 11088번 인덱스 데이터 처리 완료 => [0.9787259] 1
# 11089번 인덱스 데이터 처리 완료 => [0.9721933] 1
# 11090번 인덱스 데이터 처리 완료 => [0.15348695] 0
# 11091번 인덱스 데이터 처리 완료 => [0.21775497] 0
# 11092번 인덱스 데이터 처리 완료 => [0.1447397] 0
# 11093번 인덱스 데이터 처리 완료 => [0.06382436] 0
# 11094번 인덱스 데이터 처리 완료 => [0.623675] 1
# 11095번 인덱스 데이터 처리 완료 => [0.01704486] 0
# 11096번 인덱스 데이터 처리 완료 => [0.9964294] 1
# 11097번 인덱스 데이터 처리 완료 => [0.06172381] 0
# 11098번 인덱스 데이터 처리 완료 => [0.9627374] 1
# 11099번 인덱스 데이터 처리 완료 => [0.3377502] 0
# 11100번 인덱스 데이터 처리 완료 => [0.97487766] 1
# 11101번 인덱스 데이터 처리 완료 => [0.99999464] 1
# 11102번 인덱스 데이터 처리 완료 => [0.9603517] 1
# 11103번 인덱스 데이터 처리 완료 => [0.38450745] 0
# 11104번 인덱스 데이터 처리 완료 => [0.82578367] 1
# 11105번 인덱스 데이터 처리 완료 => [0.5328017] 1
# 11106번 인덱스 데이터 처리 완료 => [0.30241576] 0
# 11107번 인덱스 데이터 처리 완료 => [0.16881996] 0
# 11108번 인덱스 데이터 처리 완료 => [0.05351199] 0
# 11109번 인덱스 데이터 처리 완료 => [0.0005084] 0
# 11110번 인덱스 데이터 처리 완료 => [0.83990747] 1
# 11111번 인덱스 데이터 처리 완료 => [0.4957219] 0
# 11112번 인덱스 데이터 처리 완료 => [0.93078536] 1
# 11113번 인덱스 데이터 처리 완료 => [0.41407284] 0
# 11114번 인덱스 데이터 처리 완료 => [0.8617734] 1
# 11115번 인덱스 데이터 처리 완료 => [0.22880276] 0
# 11116번 인덱스 데이터 처리 완료 => [0.52559406] 1
# 11117번 인덱스 데이터 처리 완료 => [0.21108174] 0
# 11118번 인덱스 데이터 처리 완료 => [0.8853915] 1
# 11119번 인덱스 데이터 처리 완료 => [0.37136692] 0
# 11120번 인덱스 데이터 처리 완료 => [0.7370971] 1
# 11121번 인덱스 데이터 처리 완료 => [0.66759956] 1
# 11122번 인덱스 데이터 처리 완료 => [0.29737765] 0
# 11123번 인덱스 데이터 처리 완료 => [0.9246394] 1
# 11124번 인덱스 데이터 처리 완료 => [0.8327623] 1
# 11125번 인덱스 데이터 처리 완료 => [0.8034784] 1
# 11126번 인덱스 데이터 처리 완료 => [0.8279558] 1
# 11127번 인덱스 데이터 처리 완료 => [0.547959] 1
# 11128번 인덱스 데이터 처리 완료 => [0.5116055] 1
# 11129번 인덱스 데이터 처리 완료 => [0.83939356] 1
# 11130번 인덱스 데이터 처리 완료 => [0.8900893] 1
# 11131번 인덱스 데이터 처리 완료 => [0.7957537] 1
# 11132번 인덱스 데이터 처리 완료 => [0.07676703] 0
# 11133번 인덱스 데이터 처리 완료 => [0.32589188] 0
# 11134번 인덱스 데이터 처리 완료 => [0.12251695] 0
# 11135번 인덱스 데이터 처리 완료 => [0.88165027] 1
# 11136번 인덱스 데이터 처리 완료 => [0.6853605] 1
# 11137번 인덱스 데이터 처리 완료 => [0.39743832] 0
# 11138번 인덱스 데이터 처리 완료 => [0.43372977] 0
# 11139번 인덱스 데이터 처리 완료 => [0.9883322] 1
# 11140번 인덱스 데이터 처리 완료 => [0.5332494] 1
# 11141번 인덱스 데이터 처리 완료 => [0.9848103] 1
# 11142번 인덱스 데이터 처리 완료 => [0.98115623] 1
# 11143번 인덱스 데이터 처리 완료 => [0.2000551] 0
# 11144번 인덱스 데이터 처리 완료 => [0.88224393] 1
# 11145번 인덱스 데이터 처리 완료 => [0.67896044] 1
# 11146번 인덱스 데이터 처리 완료 => [0.3950549] 0
# 11147번 인덱스 데이터 처리 완료 => [0.6836044] 1
# 11148번 인덱스 데이터 처리 완료 => [0.6573072] 1
# 11149번 인덱스 데이터 처리 완료 => [0.03367653] 0
# 11150번 인덱스 데이터 처리 완료 => [0.38281775] 0
# 11151번 인덱스 데이터 처리 완료 => [0.26012713] 0
# 11152번 인덱스 데이터 처리 완료 => [0.18968028] 0
# 11153번 인덱스 데이터 처리 완료 => [0.05402247] 0
# 11154번 인덱스 데이터 처리 완료 => [0.98852754] 1
# 11155번 인덱스 데이터 처리 완료 => [0.52013874] 1
# 11156번 인덱스 데이터 처리 완료 => [0.85630286] 1
# 11157번 인덱스 데이터 처리 완료 => [0.54908264] 1
# 11158번 인덱스 데이터 처리 완료 => [0.34616992] 0
# 11159번 인덱스 데이터 처리 완료 => [0.04775599] 0
# 11160번 인덱스 데이터 처리 완료 => [0.41168803] 0
# 11161번 인덱스 데이터 처리 완료 => [0.85909003] 1
# 11162번 인덱스 데이터 처리 완료 => [0.97427285] 1
# 11163번 인덱스 데이터 처리 완료 => [0.9643529] 1
# 11164번 인덱스 데이터 처리 완료 => [0.62032557] 1
# 11165번 인덱스 데이터 처리 완료 => [0.00531819] 0
# 11166번 인덱스 데이터 처리 완료 => [0.9658085] 1
# 11167번 인덱스 데이터 처리 완료 => [0.95398915] 1
# 11168번 인덱스 데이터 처리 완료 => [0.01011011] 0
# 11169번 인덱스 데이터 처리 완료 => [0.00955825] 0
# 11170번 인덱스 데이터 처리 완료 => [0.9972228] 1
# 11171번 인덱스 데이터 처리 완료 => [0.19256312] 0
# 11172번 인덱스 데이터 처리 완료 => [0.45243567] 0
# 11173번 인덱스 데이터 처리 완료 => [0.30060217] 0
# 11174번 인덱스 데이터 처리 완료 => [0.36323836] 0
# 11175번 인덱스 데이터 처리 완료 => [0.02001671] 0
# 11176번 인덱스 데이터 처리 완료 => [0.9758009] 1
# 11177번 인덱스 데이터 처리 완료 => [0.49095654] 0
# 11178번 인덱스 데이터 처리 완료 => [0.24333934] 0
# 11179번 인덱스 데이터 처리 완료 => [0.86587864] 1
# 11180번 인덱스 데이터 처리 완료 => [0.55879325] 1
# 11181번 인덱스 데이터 처리 완료 => [0.9853108] 1
# 11182번 인덱스 데이터 처리 완료 => [0.9198456] 1
# 11183번 인덱스 데이터 처리 완료 => [0.00507866] 0
# 11184번 인덱스 데이터 처리 완료 => [0.74226665] 1
# 11185번 인덱스 데이터 처리 완료 => [0.94831806] 1
# 11186번 인덱스 데이터 처리 완료 => [0.12570806] 0
# time : 3.701218843460083

# %%
# 테스트 데이터의 리뷰 부분을 리스트 처리
test_id = list(test_data['id'])

# 판다스 데이터프레임 통해 데이터 구성하여 output에 투입
output = pd.DataFrame( data={"Id": test_id, "Predicted": test_preds} )
output.head()
# Out:
#    Id  Predicted
# 0   0          1
# 1   1          0
# 2   2          0
# 3   3          1
# 4   4          0

# %%
# 해당 경로가 없으면 생성
if not os.path.exists(DATA_OUT_PATH):
    os.makedirs(DATA_OUT_PATH)

# csv 파일 생성
output.to_csv(DATA_OUT_PATH + "NSMC_LSTM.csv", index = False)  # 앙상블 조합 및 캐글 제출 용도

# %% [markdown]
# ### 캐글 제출 결과
# **[2020.12.20]**<br>
# 0.80976

# %% [markdown]
# ---
